# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
from sklearn.metrics import average_precision_score, roc_auc_score, confusion_matrix, classification_report

# %% [markdown]
# # Load Datasets

# %%
X_train = pd.read_csv('../data/X_train.csv')
y_train = pd.read_csv('../data/y_train.csv')
X_train_resampled = pd.read_csv('../data/X_train_resampled.csv')
y_train_resampled = pd.read_csv('../data/y_train_resampled.csv')
X_val = pd.read_csv('../data/X_val.csv')
y_val = pd.read_csv('../data/y_val.csv')
X_test = pd.read_csv('../data/X_test.csv')
y_test = pd.read_csv('../data/y_test.csv')

# %% [markdown]
# # Use Log-Transformed Features

# %%
log_transformed_columns = ['days_since_request_log', 'intended_balcon_amount_log',
                           'zip_count_4w_log', 'velocity_24h_log', 'velocity_4w_log',
                           'date_of_birth_distinct_emails_4w_log','session_length_in_minutes_log']
original_columns = ['days_since_request', 'intended_balcon_amount_clean',
                    'zip_count_4w', 'velocity_24h', 'velocity_4w',
                    'date_of_birth_distinct_emails_4w', 'session_length_in_minutes_cleaned']

# %%
X_train_resampled_log = X_train_resampled.drop(columns=original_columns)
X_train_log = X_train.drop(columns=original_columns)
X_val_log = X_val.drop(columns=original_columns)
X_test_log = X_test.drop(columns=original_columns)

# %% [markdown]
# ## Use SMOTE resampled Training Data

# %% [markdown]
# ### Baseline

# %%
# Baseline XGBoost model
xgb_baseline = XGBClassifier(
    n_estimators=300,          # number of trees
    max_depth=6,               # tree depth
    learning_rate=0.2,         # step size shrinkage
    eval_metric='auc',     # evaluation metric
    random_state=42,
    n_jobs=-1                  # use all CPU cores
)

# Fit on training data
xgb_baseline.fit(X_train_resampled_log, y_train_resampled.values.ravel())
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.2, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=300,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %%
# Evaluate on Train Set
y_train_pred = xgb_baseline.predict(X_train_resampled_log)
y_train_proba = xgb_baseline.predict_proba(X_train_resampled_log)[:, 1]

# Classification report
print("Training Classification Report:\n")
print(classification_report(y_train_resampled, y_train_pred, digits=4))

# ROC-AUC
roc_auc_train = roc_auc_score(y_train_resampled, y_train_proba)
print(f"Training ROC-AUC Score: {roc_auc_train:.4f}")

# PR-AUC
pr_auc_train = average_precision_score(y_train_resampled, y_train_proba)
print(f"Training PR-AUC Score: {pr_auc_train:.4f}")

# Confusion matrix
print("Training Confusion Matrix:\n", confusion_matrix(y_train_resampled, y_train_pred))
# Out:
# Training Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9911    0.9997    0.9954    786838
#            1     0.9997    0.9910    0.9954    786838
#
#     accuracy                         0.9954   1573676
#    macro avg     0.9954    0.9954    0.9954   1573676
# weighted avg     0.9954    0.9954    0.9954   1573676
#
# Training ROC-AUC Score: 0.9996
# Training PR-AUC Score: 0.9996
# Training Confusion Matrix:
#  [[786630    208]
#  [  7043 779795]]

# %%
# Evaluate on Validation Set
y_val_pred = xgb_baseline.predict(X_val_log)
y_val_proba = xgb_baseline.predict_proba(X_val_log)[:, 1]

# Classification report
print("\nValidation Classification Report:\n")
print(classification_report(y_val, y_val_pred, digits=4))

# ROC-AUC
roc_auc_val = roc_auc_score(y_val, y_val_proba)
print(f"Validation ROC-AUC Score: {roc_auc_val:.4f}")

# PR-AUC
pr_auc_val = average_precision_score(y_val, y_val_proba)
print(f"Validation PR-AUC Score: {pr_auc_val:.4f}")

# Confusion matrix
print("Validation Confusion Matrix:\n", confusion_matrix(y_val, y_val_pred))
# Out:
# Validation Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9875    0.9983    0.9929    106718
#            1     0.3599    0.0717    0.1196      1450
#
#     accuracy                         0.9858    108168
#    macro avg     0.6737    0.5350    0.5562    108168
# weighted avg     0.9791    0.9858    0.9812    108168
#
# Validation ROC-AUC Score: 0.8789
# Validation PR-AUC Score: 0.1490
# Validation Confusion Matrix:
#  [[106533    185]
#  [  1346    104]]

# %% [markdown]
# ### Hyperparameter Tuning

# %%
import optuna
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score

def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 200, 800),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 0.5),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "eval_metric": "auc",
        "random_state": 42,
        "n_jobs": -1
    }

    model = XGBClassifier(**params)

    auc = cross_val_score(
        model,
        X_train_resampled_log,
        y_train_resampled.values.ravel(),
        scoring="roc_auc",
        cv=5,
        n_jobs=-1
    ).mean()

    return auc

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)

print("Best params:", study.best_params)
print("Best AUC:", study.best_value)
# Out:
# [I 2025-11-07 13:21:43,052] A new study created in memory with name: no-name-861949dd-cb40-4589-848f-3b6cd3ddd198
# [I 2025-11-07 13:22:09,098] Trial 0 finished with value: 0.9811942308008745 and parameters: {'n_estimators': 218, 'max_depth': 5, 'learning_rate': 0.1381595665075031, 'subsample': 0.6333449702682407, 'colsample_bytree': 0.9231590858482497, 'gamma': 0.2367807107309881, 'min_child_weight': 9}. Best is trial 0 with value: 0.9811942308008745.
# [I 2025-11-07 13:23:48,946] Trial 1 finished with value: 0.9808178488112913 and parameters: {'n_estimators': 732, 'max_depth': 8, 'learning_rate': 0.043316151420247605, 'subsample': 0.9054730990298401, 'colsample_bytree': 0.8967971077161351, 'gamma': 0.2403394229617135, 'min_child_weight': 1}. Best is trial 0 with value: 0.9811942308008745.
# [I 2025-11-07 13:25:19,526] Trial 2 finished with value: 0.9885897313826121 and parameters: {'n_estimators': 584, 'max_depth': 10, 'learning_rate': 0.18640620979411388, 'subsample': 0.9601154145663083, 'colsample_bytree': 0.9026945430391118, 'gamma': 0.07838259717187568, 'min_child_weight': 1}. Best is trial 2 with value: 0.9885897313826121.
# [I 2025-11-07 13:25:56,192] Trial 3 finished with value: 0.9856177177155431 and parameters: {'n_estimators': 406, 'max_depth': 4, 'learning_rate': 0.18543479639971233, 'subsample': 0.9534829564979985, 'colsample_bytree': 0.6753607453592378, 'gamma': 0.4041847371980501, 'min_child_weight': 6}. Best is trial 2 with value: 0.9885897313826121.
# [I 2025-11-07 13:26:41,446] Trial 4 finished with value: 0.9884591807136965 and parameters: {'n_estimators': 390, 'max_depth': 6, 'learning_rate': 0.20632156394382953, 'subsample': 0.9623600908450658, 'colsample_bytree': 0.6703094340444206, 'gamma': 0.17352770402150547, 'min_child_weight': 9}. Best is trial 2 with value: 0.9885897313826121.
# [I 2025-11-07 13:27:38,660] Trial 5 finished with value: 0.989421649814819 and parameters: {'n_estimators': 602, 'max_depth': 5, 'learning_rate': 0.29849667806017155, 'subsample': 0.8074116628716752, 'colsample_bytree': 0.7350288369175187, 'gamma': 0.4499548562986797, 'min_child_weight': 10}. Best is trial 5 with value: 0.989421649814819.
# [I 2025-11-07 13:29:10,387] Trial 6 finished with value: 0.9896769546254625 and parameters: {'n_estimators': 722, 'max_depth': 9, 'learning_rate': 0.27126208864130796, 'subsample': 0.7833124250026051, 'colsample_bytree': 0.8265655471384172, 'gamma': 0.43249673861625104, 'min_child_weight': 6}. Best is trial 6 with value: 0.9896769546254625.
# [I 2025-11-07 13:29:40,899] Trial 7 finished with value: 0.9830452721442848 and parameters: {'n_estimators': 379, 'max_depth': 3, 'learning_rate': 0.23642290123812792, 'subsample': 0.9711701129220419, 'colsample_bytree': 0.6561932872655483, 'gamma': 0.24847112327089615, 'min_child_weight': 3}. Best is trial 6 with value: 0.9896769546254625.
# [I 2025-11-07 13:31:38,307] Trial 8 finished with value: 0.9886284349805179 and parameters: {'n_estimators': 717, 'max_depth': 10, 'learning_rate': 0.06537262811502376, 'subsample': 0.7549453654563005, 'colsample_bytree': 0.9420574433193283, 'gamma': 0.14556460273829658, 'min_child_weight': 5}. Best is trial 6 with value: 0.9896769546254625.
# [I 2025-11-07 13:32:28,133] Trial 9 finished with value: 0.9859682659515775 and parameters: {'n_estimators': 550, 'max_depth': 4, 'learning_rate': 0.19998916883804185, 'subsample': 0.6498238781474022, 'colsample_bytree': 0.937165694818748, 'gamma': 0.4895928876649271, 'min_child_weight': 3}. Best is trial 6 with value: 0.9896769546254625.
# [I 2025-11-07 13:34:05,387] Trial 10 finished with value: 0.9897112411378994 and parameters: {'n_estimators': 776, 'max_depth': 8, 'learning_rate': 0.2937395642905177, 'subsample': 0.7957590094630451, 'colsample_bytree': 0.794173094553279, 'gamma': 0.35835490646880047, 'min_child_weight': 6}. Best is trial 10 with value: 0.9897112411378994.
# [I 2025-11-07 13:35:44,311] Trial 11 finished with value: 0.9895197827139441 and parameters: {'n_estimators': 757, 'max_depth': 8, 'learning_rate': 0.29346401395141997, 'subsample': 0.8002431452082485, 'colsample_bytree': 0.8125456156034906, 'gamma': 0.3491093555197212, 'min_child_weight': 7}. Best is trial 10 with value: 0.9897112411378994.
# [I 2025-11-07 13:37:31,790] Trial 12 finished with value: 0.9898299039378203 and parameters: {'n_estimators': 785, 'max_depth': 8, 'learning_rate': 0.26083997839722906, 'subsample': 0.7202774367008961, 'colsample_bytree': 0.8027743007939748, 'gamma': 0.36193611785214197, 'min_child_weight': 7}. Best is trial 12 with value: 0.9898299039378203.
# [I 2025-11-07 13:39:09,936] Trial 13 finished with value: 0.9894311210786386 and parameters: {'n_estimators': 795, 'max_depth': 7, 'learning_rate': 0.2517429428447689, 'subsample': 0.7058169080562076, 'colsample_bytree': 0.7535028382343494, 'gamma': 0.337610897399586, 'min_child_weight': 8}. Best is trial 12 with value: 0.9898299039378203.
# [I 2025-11-07 13:40:34,222] Trial 14 finished with value: 0.9883082906881047 and parameters: {'n_estimators': 644, 'max_depth': 8, 'learning_rate': 0.11969519938891561, 'subsample': 0.8828064446551345, 'colsample_bytree': 0.8480882450795444, 'gamma': 0.32187499902163463, 'min_child_weight': 4}. Best is trial 12 with value: 0.9898299039378203.
# [I 2025-11-07 13:41:56,601] Trial 15 finished with value: 0.9891827122380648 and parameters: {'n_estimators': 668, 'max_depth': 7, 'learning_rate': 0.2358949499567064, 'subsample': 0.7173446362103933, 'colsample_bytree': 0.7398388706789799, 'gamma': 0.3775218637264563, 'min_child_weight': 7}. Best is trial 12 with value: 0.9898299039378203.
# [I 2025-11-07 13:43:07,168] Trial 16 finished with value: 0.9892003707263797 and parameters: {'n_estimators': 485, 'max_depth': 9, 'learning_rate': 0.265367932389446, 'subsample': 0.8607836713090649, 'colsample_bytree': 0.7761769854647719, 'gamma': 0.3037358481362603, 'min_child_weight': 5}. Best is trial 12 with value: 0.9898299039378203.
# [I 2025-11-07 13:44:36,533] Trial 17 finished with value: 0.9874196176767015 and parameters: {'n_estimators': 789, 'max_depth': 6, 'learning_rate': 0.07867846656077263, 'subsample': 0.6904152870231687, 'colsample_bytree': 0.9894033753928496, 'gamma': 0.2884950173895109, 'min_child_weight': 7}. Best is trial 12 with value: 0.9898299039378203.
# [I 2025-11-07 13:46:05,566] Trial 18 finished with value: 0.9897815110881665 and parameters: {'n_estimators': 669, 'max_depth': 9, 'learning_rate': 0.2211027920971222, 'subsample': 0.8302267448323594, 'colsample_bytree': 0.8518569307794156, 'gamma': 0.47478013303509714, 'min_child_weight': 8}. Best is trial 12 with value: 0.9898299039378203.
# [I 2025-11-07 13:47:39,722] Trial 19 finished with value: 0.9905866826943546 and parameters: {'n_estimators': 663, 'max_depth': 9, 'learning_rate': 0.1623475105572509, 'subsample': 0.8406399429727966, 'colsample_bytree': 0.603324899992376, 'gamma': 0.48927833192084563, 'min_child_weight': 10}. Best is trial 19 with value: 0.9905866826943546.
# [I 2025-11-07 13:48:58,174] Trial 20 finished with value: 0.9906132480837473 and parameters: {'n_estimators': 481, 'max_depth': 10, 'learning_rate': 0.15792742525557002, 'subsample': 0.7497372319612025, 'colsample_bytree': 0.607044441007861, 'gamma': 0.40732611117875384, 'min_child_weight': 10}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 13:50:13,828] Trial 21 finished with value: 0.9904453527642814 and parameters: {'n_estimators': 468, 'max_depth': 10, 'learning_rate': 0.1568437586047061, 'subsample': 0.730628870859626, 'colsample_bytree': 0.6007911539215443, 'gamma': 0.4138519778292002, 'min_child_weight': 10}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 13:51:30,527] Trial 22 finished with value: 0.9905663997913925 and parameters: {'n_estimators': 474, 'max_depth': 10, 'learning_rate': 0.15783226438783934, 'subsample': 0.7553349248029698, 'colsample_bytree': 0.6087578693556923, 'gamma': 0.49572764308462247, 'min_child_weight': 10}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 13:52:24,174] Trial 23 finished with value: 0.990312465190132 and parameters: {'n_estimators': 316, 'max_depth': 10, 'learning_rate': 0.10661737668590117, 'subsample': 0.758813018821829, 'colsample_bytree': 0.6008485131761838, 'gamma': 0.48694318064276193, 'min_child_weight': 10}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 13:53:40,050] Trial 24 finished with value: 0.9900148386573286 and parameters: {'n_estimators': 530, 'max_depth': 9, 'learning_rate': 0.16922049479102982, 'subsample': 0.8489665100547779, 'colsample_bytree': 0.6457573515921404, 'gamma': 0.4988113185904131, 'min_child_weight': 9}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 13:54:53,442] Trial 25 finished with value: 0.9899746505399241 and parameters: {'n_estimators': 444, 'max_depth': 10, 'learning_rate': 0.1412505009289827, 'subsample': 0.6733259218017448, 'colsample_bytree': 0.7016329954213226, 'gamma': 0.002178566522826275, 'min_child_weight': 10}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 13:55:46,771] Trial 26 finished with value: 0.9893080534949341 and parameters: {'n_estimators': 345, 'max_depth': 9, 'learning_rate': 0.10764617051532593, 'subsample': 0.920732100632867, 'colsample_bytree': 0.642581601792937, 'gamma': 0.45052552061254625, 'min_child_weight': 9}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 13:57:09,018] Trial 27 finished with value: 0.990209874465535 and parameters: {'n_estimators': 507, 'max_depth': 10, 'learning_rate': 0.17110239678561762, 'subsample': 0.7626526861596028, 'colsample_bytree': 0.622844579101618, 'gamma': 0.40087055563360235, 'min_child_weight': 8}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 13:58:31,298] Trial 28 finished with value: 0.990485426804403 and parameters: {'n_estimators': 567, 'max_depth': 9, 'learning_rate': 0.12965330558953173, 'subsample': 0.8313849552446081, 'colsample_bytree': 0.6901001378280776, 'gamma': 0.45079584976454856, 'min_child_weight': 10}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 13:59:05,552] Trial 29 finished with value: 0.9859002868111737 and parameters: {'n_estimators': 242, 'max_depth': 7, 'learning_rate': 0.08898398456825618, 'subsample': 0.6144335873386488, 'colsample_bytree': 0.7038311999281314, 'gamma': 0.19456161646440875, 'min_child_weight': 9}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:00:21,156] Trial 30 finished with value: 0.9898842000023557 and parameters: {'n_estimators': 440, 'max_depth': 10, 'learning_rate': 0.14181329905602796, 'subsample': 0.6595047871136716, 'colsample_bytree': 0.6281450943585318, 'gamma': 0.2800805155181141, 'min_child_weight': 8}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:01:47,512] Trial 31 finished with value: 0.990238177762012 and parameters: {'n_estimators': 580, 'max_depth': 9, 'learning_rate': 0.12494813716876643, 'subsample': 0.8351920782535552, 'colsample_bytree': 0.6912162045767801, 'gamma': 0.45179858778476134, 'min_child_weight': 10}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:03:19,831] Trial 32 finished with value: 0.9904688164963777 and parameters: {'n_estimators': 633, 'max_depth': 9, 'learning_rate': 0.15537040114738065, 'subsample': 0.8820979927381949, 'colsample_bytree': 0.6211055324491774, 'gamma': 0.45944240333604486, 'min_child_weight': 9}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:05:03,058] Trial 33 finished with value: 0.9803257110873137 and parameters: {'n_estimators': 543, 'max_depth': 10, 'learning_rate': 0.011532971632477865, 'subsample': 0.7442580874042004, 'colsample_bytree': 0.6027782015037043, 'gamma': 0.3987369479598707, 'min_child_weight': 10}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:06:30,741] Trial 34 finished with value: 0.9902129487352035 and parameters: {'n_estimators': 578, 'max_depth': 9, 'learning_rate': 0.1733210759035282, 'subsample': 0.7746407370521717, 'colsample_bytree': 0.6691428300041136, 'gamma': 0.42643071849773184, 'min_child_weight': 10}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:07:40,067] Trial 35 finished with value: 0.9892706971327041 and parameters: {'n_estimators': 502, 'max_depth': 8, 'learning_rate': 0.19526852459989003, 'subsample': 0.81807465992806, 'colsample_bytree': 0.7161658684234433, 'gamma': 0.49923627629249057, 'min_child_weight': 9}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:09:10,851] Trial 36 finished with value: 0.9904472525205282 and parameters: {'n_estimators': 609, 'max_depth': 10, 'learning_rate': 0.13133173458259098, 'subsample': 0.9378651482752303, 'colsample_bytree': 0.6784715217757746, 'gamma': 0.38447395453736505, 'min_child_weight': 9}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:10:14,697] Trial 37 finished with value: 0.9900158840523037 and parameters: {'n_estimators': 423, 'max_depth': 9, 'learning_rate': 0.148799680638942, 'subsample': 0.8776539753804106, 'colsample_bytree': 0.6386050050444967, 'gamma': 0.42994367441009623, 'min_child_weight': 10}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:11:45,820] Trial 38 finished with value: 0.9873071425544617 and parameters: {'n_estimators': 674, 'max_depth': 8, 'learning_rate': 0.1851485792432524, 'subsample': 0.7787719627329602, 'colsample_bytree': 0.6607714456196156, 'gamma': 0.471489951317639, 'min_child_weight': 1}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:12:59,916] Trial 39 finished with value: 0.990209847277411 and parameters: {'n_estimators': 463, 'max_depth': 10, 'learning_rate': 0.2176614126201355, 'subsample': 0.8527131695676193, 'colsample_bytree': 0.6196635714713935, 'gamma': 0.42817586063347635, 'min_child_weight': 8}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:14:20,049] Trial 40 finished with value: 0.9895135789205171 and parameters: {'n_estimators': 702, 'max_depth': 6, 'learning_rate': 0.10363409096318763, 'subsample': 0.826269988689544, 'colsample_bytree': 0.7181708433913226, 'gamma': 0.4645154612582322, 'min_child_weight': 10}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:15:27,311] Trial 41 finished with value: 0.9894311618703657 and parameters: {'n_estimators': 630, 'max_depth': 9, 'learning_rate': 0.15602899259085123, 'subsample': 0.9952908106209092, 'colsample_bytree': 0.6224326106348305, 'gamma': 0.462241868612354, 'min_child_weight': 9}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:16:43,780] Trial 42 finished with value: 0.9901695187387368 and parameters: {'n_estimators': 525, 'max_depth': 9, 'learning_rate': 0.15920811035639462, 'subsample': 0.8978806161041973, 'colsample_bytree': 0.6494677138954518, 'gamma': 0.44200626181035857, 'min_child_weight': 9}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:18:08,035] Trial 43 finished with value: 0.9901709138791077 and parameters: {'n_estimators': 558, 'max_depth': 10, 'learning_rate': 0.1892100961439288, 'subsample': 0.8765516191560941, 'colsample_bytree': 0.6228147157955519, 'gamma': 0.4718499765975737, 'min_child_weight': 10}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:19:12,785] Trial 44 finished with value: 0.9889351031029218 and parameters: {'n_estimators': 618, 'max_depth': 5, 'learning_rate': 0.11947102690577122, 'subsample': 0.8098283736011774, 'colsample_bytree': 0.6802754736554198, 'gamma': 0.10343380693296542, 'min_child_weight': 9}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:20:11,332] Trial 45 finished with value: 0.9899373016648833 and parameters: {'n_estimators': 375, 'max_depth': 9, 'learning_rate': 0.1756667908973011, 'subsample': 0.7889386243132136, 'colsample_bytree': 0.6136738225906591, 'gamma': 0.4111783047671245, 'min_child_weight': 10}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:21:14,713] Trial 46 finished with value: 0.9886925308276379 and parameters: {'n_estimators': 696, 'max_depth': 4, 'learning_rate': 0.21060479223167378, 'subsample': 0.9145064838670067, 'colsample_bytree': 0.6605046852375778, 'gamma': 0.2188324469779526, 'min_child_weight': 9}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:22:11,038] Trial 47 finished with value: 0.9880831752719516 and parameters: {'n_estimators': 739, 'max_depth': 3, 'learning_rate': 0.14085342205064882, 'subsample': 0.8978929356236629, 'colsample_bytree': 0.6395316676363704, 'gamma': 0.37788974644011203, 'min_child_weight': 8}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:23:40,591] Trial 48 finished with value: 0.9900354596472518 and parameters: {'n_estimators': 641, 'max_depth': 8, 'learning_rate': 0.16219837819884997, 'subsample': 0.7379965874482032, 'colsample_bytree': 0.6343015395306743, 'gamma': 0.4834451410366467, 'min_child_weight': 10}. Best is trial 20 with value: 0.9906132480837473.
# [I 2025-11-07 14:24:51,705] Trial 49 finished with value: 0.9884422585644451 and parameters: {'n_estimators': 591, 'max_depth': 7, 'learning_rate': 0.1311496001008655, 'subsample': 0.8639068678066718, 'colsample_bytree': 0.6051739405996089, 'gamma': 0.4491960931446184, 'min_child_weight': 3}. Best is trial 20 with value: 0.9906132480837473.
# Best params: {'n_estimators': 481, 'max_depth': 10, 'learning_rate': 0.15792742525557002, 'subsample': 0.7497372319612025, 'colsample_bytree': 0.607044441007861, 'gamma': 0.40732611117875384, 'min_child_weight': 10}
# Best AUC: 0.9906132480837473

# %%
# Extract best parameters
best_params = study.best_params  # from your Optuna study

# Optional: add fixed parameters
best_params.update({
    "eval_metric": "auc",
    "random_state": 42,
    "n_jobs": -1
})

# Train final model on full training set
final_model = XGBClassifier(**best_params)
final_model.fit(X_train_resampled_log, y_train_resampled.values.ravel())
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.607044441007861, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='auc', feature_types=None, feature_weights=None,
#               gamma=0.40732611117875384, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.15792742525557002,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=10, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=481, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %%
# Evaluate final model on train set
y_train_final_pred = final_model.predict(X_train_resampled_log)
y_train_final_proba = final_model.predict_proba(X_train_resampled_log)[:, 1]

# classification report
print("Final Model Training Classification Report:\n")
print(classification_report(y_train_resampled, y_train_final_pred, digits=4))

# roc auc
roc_auc_train_final = roc_auc_score(y_train_resampled, y_train_final_proba)
print(f"Final Model Training ROC-AUC Score: {roc_auc_train_final:.4f}")

# pr auc
pr_auc_train_final = average_precision_score(y_train_resampled, y_train_final_proba)
print(f"Final Model Training PR-AUC Score: {pr_auc_train_final:.4f}")

# confusion matrix
print("Final Model Training Confusion Matrix:\n", confusion_matrix(y_train_resampled, y_train_final_pred))
# Out:
# Final Model Training Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9959    1.0000    0.9979    786838
#            1     1.0000    0.9959    0.9979    786838
#
#     accuracy                         0.9979   1573676
#    macro avg     0.9979    0.9979    0.9979   1573676
# weighted avg     0.9979    0.9979    0.9979   1573676
#
# Final Model Training ROC-AUC Score: 1.0000
# Final Model Training PR-AUC Score: 1.0000
# Final Model Training Confusion Matrix:
#  [[786828     10]
#  [  3238 783600]]

# %%
# Evaluate final model on validation set
y_val_final_pred = final_model.predict(X_val_log)
y_val_final_proba = final_model.predict_proba(X_val_log)[:, 1]

# classification report
print("\nFinal Model Validation Classification Report:\n")
print(classification_report(y_val, y_val_final_pred, digits=4))

# roc auc
roc_auc_val_final = roc_auc_score(y_val, y_val_final_proba)
print(f"Final Model Validation ROC-AUC Score: {roc_auc_val_final:.4f}")

# pr auc
pr_auc_val_final = average_precision_score(y_val, y_val_final_proba)
print(f"Final Model Validation PR-AUC Score: {pr_auc_val_final:.4f}")

# confusion matrix
print("Final Model Validation Confusion Matrix:\n", confusion_matrix(y_val, y_val_final_pred))
# Out:
# Final Model Validation Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9874    0.9986    0.9929    106718
#            1     0.3598    0.0593    0.1018      1450
#
#     accuracy                         0.9860    108168
#    macro avg     0.6736    0.5289    0.5474    108168
# weighted avg     0.9789    0.9860    0.9810    108168
#
# Final Model Validation ROC-AUC Score: 0.8655
# Final Model Validation PR-AUC Score: 0.1282
# Final Model Validation Confusion Matrix:
#  [[106565    153]
#  [  1364     86]]
