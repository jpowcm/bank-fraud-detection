# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
from sklearn.metrics import average_precision_score, roc_auc_score, confusion_matrix, classification_report

# %% [markdown]
# # Load Datasets

# %%
X_train = pd.read_csv('../data/X_train.csv')
y_train = pd.read_csv('../data/y_train.csv')
X_train_resampled = pd.read_csv('../data/X_train_resampled.csv')
y_train_resampled = pd.read_csv('../data/y_train_resampled.csv')
X_val = pd.read_csv('../data/X_val.csv')
y_val = pd.read_csv('../data/y_val.csv')
X_test = pd.read_csv('../data/X_test.csv')
y_test = pd.read_csv('../data/y_test.csv')

# %% [markdown]
# # Use Log-Transformed Features

# %%
log_transformed_columns = ['days_since_request_log', 'intended_balcon_amount_log',
                           'zip_count_4w_log', 'velocity_24h_log', 'velocity_4w_log',
                           'date_of_birth_distinct_emails_4w_log','session_length_in_minutes_log']
original_columns = ['days_since_request', 'intended_balcon_amount_clean',
                    'zip_count_4w', 'velocity_24h', 'velocity_4w',
                    'date_of_birth_distinct_emails_4w', 'session_length_in_minutes_cleaned']

# %%
X_train_resampled_log = X_train_resampled.drop(columns=original_columns)
X_train_log = X_train.drop(columns=original_columns)
X_val_log = X_val.drop(columns=original_columns)
X_test_log = X_test.drop(columns=original_columns)

# %% [markdown]
# ## Use SMOTE resampled Training Data

# %% [markdown]
# ### Baseline

# %%
# Baseline XGBoost model
xgb_baseline = XGBClassifier(
    n_estimators=300,          # number of trees
    max_depth=6,               # tree depth
    learning_rate=0.2,         # step size shrinkage
    eval_metric='auc',     # evaluation metric
    random_state=42,
    n_jobs=-1                  # use all CPU cores
)

# Fit on training data
xgb_baseline.fit(X_train_resampled_log, y_train_resampled.values.ravel())
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.2, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=300,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %%
# Evaluate on Train Set
y_train_pred = xgb_baseline.predict(X_train_resampled_log)
y_train_proba = xgb_baseline.predict_proba(X_train_resampled_log)[:, 1]

# Classification report
print("Training Classification Report:\n")
print(classification_report(y_train_resampled, y_train_pred, digits=4))

# ROC-AUC
roc_auc_train = roc_auc_score(y_train_resampled, y_train_proba)
print(f"Training ROC-AUC Score: {roc_auc_train:.4f}")

# PR-AUC
pr_auc_train = average_precision_score(y_train_resampled, y_train_proba)
print(f"Training PR-AUC Score: {pr_auc_train:.4f}")

# Confusion matrix
print("Training Confusion Matrix:\n", confusion_matrix(y_train_resampled, y_train_pred))
# Out:
# Training Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9911    0.9997    0.9954    786838
#            1     0.9997    0.9910    0.9954    786838
#
#     accuracy                         0.9954   1573676
#    macro avg     0.9954    0.9954    0.9954   1573676
# weighted avg     0.9954    0.9954    0.9954   1573676
#
# Training ROC-AUC Score: 0.9996
# Training PR-AUC Score: 0.9996
# Training Confusion Matrix:
#  [[786630    208]
#  [  7043 779795]]

# %%
# Evaluate on Validation Set
y_val_pred = xgb_baseline.predict(X_val_log)
y_val_proba = xgb_baseline.predict_proba(X_val_log)[:, 1]

# Classification report
print("\nValidation Classification Report:\n")
print(classification_report(y_val, y_val_pred, digits=4))

# ROC-AUC
roc_auc_val = roc_auc_score(y_val, y_val_proba)
print(f"Validation ROC-AUC Score: {roc_auc_val:.4f}")

# PR-AUC
pr_auc_val = average_precision_score(y_val, y_val_proba)
print(f"Validation PR-AUC Score: {pr_auc_val:.4f}")

# Confusion matrix
print("Validation Confusion Matrix:\n", confusion_matrix(y_val, y_val_pred))
# Out:
# Validation Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9875    0.9983    0.9929    106718
#            1     0.3599    0.0717    0.1196      1450
#
#     accuracy                         0.9858    108168
#    macro avg     0.6737    0.5350    0.5562    108168
# weighted avg     0.9791    0.9858    0.9812    108168
#
# Validation ROC-AUC Score: 0.8789
# Validation PR-AUC Score: 0.1490
# Validation Confusion Matrix:
#  [[106533    185]
#  [  1346    104]]

# %%
# Evaluate on Test Set
y_test_pred = xgb_baseline.predict(X_test_log)
y_test_proba = xgb_baseline.predict_proba(X_test_log)[:, 1]
# Classification report
print("\nTest Classification Report:\n")
print(classification_report(y_test, y_test_pred, digits=4))
# ROC-AUC
roc_auc_test = roc_auc_score(y_test, y_test_proba)
print(f"Test ROC-AUC Score: {roc_auc_test:.4f}")
# PR-AUC
pr_auc_test = average_precision_score(y_test, y_test_proba)
print(f"Test PR-AUC Score: {pr_auc_test:.4f}")
# Confusion matrix
print("Test Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred))
# Out:
# Test Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9864    0.9985    0.9924     95415
#            1     0.4406    0.0805    0.1362      1428
#
#     accuracy                         0.9849     96843
#    macro avg     0.7135    0.5395    0.5643     96843
# weighted avg     0.9784    0.9849    0.9798     96843
#
# Test ROC-AUC Score: 0.8729
# Test PR-AUC Score: 0.1768
# Test Confusion Matrix:
#  [[95269   146]
#  [ 1313   115]]

# %% [markdown]
# ### Hyperparameter Tuning

# %%
import optuna

def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 200, 800),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 0.5),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "eval_metric": "auc",
        "random_state": 42,
        "n_jobs": -1
    }

    model = XGBClassifier(**params)

    model.fit(
        X_train_resampled_log, 
        y_train_resampled.values.ravel(),
        eval_set=[(X_val_log, y_val)],
        verbose=False
    )

    # Predict on validation
    preds = model.predict_proba(X_val_log)[:, 1]
    auc = roc_auc_score(y_val, preds)

    return auc

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)

print("Best params:", study.best_params)
print("Best AUC:", study.best_value)
# Out:
# [I 2025-11-08 20:22:39,036] A new study created in memory with name: no-name-d08f9e6b-b7cb-40e9-b914-79eba0cfa3fd
# [I 2025-11-08 20:22:58,396] Trial 0 finished with value: 0.8893273603457645 and parameters: {'n_estimators': 602, 'max_depth': 5, 'learning_rate': 0.09519720139712477, 'subsample': 0.672171637740313, 'colsample_bytree': 0.6765453247250416, 'gamma': 0.38207639826386824, 'min_child_weight': 10}. Best is trial 0 with value: 0.8893273603457645.
# [I 2025-11-08 20:23:21,681] Trial 1 finished with value: 0.8644349917378125 and parameters: {'n_estimators': 513, 'max_depth': 9, 'learning_rate': 0.1451563703473274, 'subsample': 0.7019463479975395, 'colsample_bytree': 0.6707323037397678, 'gamma': 0.35382553907270564, 'min_child_weight': 4}. Best is trial 0 with value: 0.8893273603457645.
# [I 2025-11-08 20:23:34,729] Trial 2 finished with value: 0.8835272141661136 and parameters: {'n_estimators': 303, 'max_depth': 8, 'learning_rate': 0.07780931339221629, 'subsample': 0.612189365614459, 'colsample_bytree': 0.9238808176758795, 'gamma': 0.054552807535416525, 'min_child_weight': 3}. Best is trial 0 with value: 0.8893273603457645.
# [I 2025-11-08 20:23:57,003] Trial 3 finished with value: 0.8635661727879664 and parameters: {'n_estimators': 479, 'max_depth': 10, 'learning_rate': 0.14804563233638424, 'subsample': 0.6358274782423731, 'colsample_bytree': 0.8874965082076085, 'gamma': 0.10744595721040551, 'min_child_weight': 10}. Best is trial 0 with value: 0.8893273603457645.
# [I 2025-11-08 20:24:17,609] Trial 4 finished with value: 0.8887121133299427 and parameters: {'n_estimators': 687, 'max_depth': 4, 'learning_rate': 0.07818384101874791, 'subsample': 0.7815085087789265, 'colsample_bytree': 0.9182669460742938, 'gamma': 0.28848185236254104, 'min_child_weight': 4}. Best is trial 0 with value: 0.8893273603457645.
# [I 2025-11-08 20:24:35,005] Trial 5 finished with value: 0.853626224706946 and parameters: {'n_estimators': 442, 'max_depth': 8, 'learning_rate': 0.27830855091558415, 'subsample': 0.9832431228284955, 'colsample_bytree': 0.7531046927723483, 'gamma': 0.20778511203762168, 'min_child_weight': 4}. Best is trial 0 with value: 0.8893273603457645.
# [I 2025-11-08 20:25:00,483] Trial 6 finished with value: 0.8412756953388595 and parameters: {'n_estimators': 523, 'max_depth': 10, 'learning_rate': 0.29532537460066394, 'subsample': 0.7406693798885514, 'colsample_bytree': 0.7324157110246595, 'gamma': 0.3702065302550016, 'min_child_weight': 10}. Best is trial 0 with value: 0.8893273603457645.
# [I 2025-11-08 20:25:24,856] Trial 7 finished with value: 0.855500380958905 and parameters: {'n_estimators': 649, 'max_depth': 7, 'learning_rate': 0.2709037235888828, 'subsample': 0.7843787694788662, 'colsample_bytree': 0.7734385197903119, 'gamma': 0.16371446466019562, 'min_child_weight': 10}. Best is trial 0 with value: 0.8893273603457645.
# [I 2025-11-08 20:25:53,548] Trial 8 finished with value: 0.8609783244399839 and parameters: {'n_estimators': 611, 'max_depth': 10, 'learning_rate': 0.16169315374388954, 'subsample': 0.8437379242842413, 'colsample_bytree': 0.6004683662433185, 'gamma': 0.1122258766615234, 'min_child_weight': 3}. Best is trial 0 with value: 0.8893273603457645.
# [I 2025-11-08 20:26:02,819] Trial 9 finished with value: 0.872821108936152 and parameters: {'n_estimators': 219, 'max_depth': 8, 'learning_rate': 0.22192844257665567, 'subsample': 0.9320783980985948, 'colsample_bytree': 0.8739950149981899, 'gamma': 0.39822231035391775, 'min_child_weight': 7}. Best is trial 0 with value: 0.8893273603457645.
# [I 2025-11-08 20:26:26,708] Trial 10 finished with value: 0.8657082572115619 and parameters: {'n_estimators': 790, 'max_depth': 4, 'learning_rate': 0.013351463490173604, 'subsample': 0.687960481728681, 'colsample_bytree': 0.6640722404637278, 'gamma': 0.4892006224337535, 'min_child_weight': 7}. Best is trial 0 with value: 0.8893273603457645.
# [I 2025-11-08 20:26:47,900] Trial 11 finished with value: 0.8894577943416455 and parameters: {'n_estimators': 742, 'max_depth': 4, 'learning_rate': 0.06726962498309717, 'subsample': 0.8741362696465391, 'colsample_bytree': 0.9994431860648565, 'gamma': 0.2844779758257081, 'min_child_weight': 1}. Best is trial 11 with value: 0.8894577943416455.
# [I 2025-11-08 20:27:11,042] Trial 12 finished with value: 0.8894458518131253 and parameters: {'n_estimators': 759, 'max_depth': 5, 'learning_rate': 0.06930546993435222, 'subsample': 0.86550957759134, 'colsample_bytree': 0.9834728052425972, 'gamma': 0.28224688703741063, 'min_child_weight': 8}. Best is trial 11 with value: 0.8894577943416455.
# [I 2025-11-08 20:27:31,200] Trial 13 finished with value: 0.8605211058988207 and parameters: {'n_estimators': 783, 'max_depth': 3, 'learning_rate': 0.015456044211997533, 'subsample': 0.8808953621820882, 'colsample_bytree': 0.9773372119472835, 'gamma': 0.2770472308646115, 'min_child_weight': 1}. Best is trial 11 with value: 0.8894577943416455.
# [I 2025-11-08 20:27:55,503] Trial 14 finished with value: 0.8890327327387488 and parameters: {'n_estimators': 721, 'max_depth': 6, 'learning_rate': 0.05714454348964264, 'subsample': 0.8672622332662423, 'colsample_bytree': 0.9956218228284248, 'gamma': 0.2457726721739266, 'min_child_weight': 7}. Best is trial 11 with value: 0.8894577943416455.
# [I 2025-11-08 20:28:18,145] Trial 15 finished with value: 0.8866347402209238 and parameters: {'n_estimators': 717, 'max_depth': 5, 'learning_rate': 0.11582140704843044, 'subsample': 0.9377539778974564, 'colsample_bytree': 0.8463755710852602, 'gamma': 0.3022852675348944, 'min_child_weight': 1}. Best is trial 11 with value: 0.8894577943416455.
# [I 2025-11-08 20:28:39,778] Trial 16 finished with value: 0.877629185135688 and parameters: {'n_estimators': 800, 'max_depth': 3, 'learning_rate': 0.05060497225871934, 'subsample': 0.8339692172949411, 'colsample_bytree': 0.9563197402807535, 'gamma': 0.20343161534965665, 'min_child_weight': 8}. Best is trial 11 with value: 0.8894577943416455.
# [I 2025-11-08 20:28:59,191] Trial 17 finished with value: 0.8749003658368721 and parameters: {'n_estimators': 578, 'max_depth': 6, 'learning_rate': 0.19061861887307857, 'subsample': 0.8956684674478607, 'colsample_bytree': 0.8232816995698665, 'gamma': 0.3336978032320741, 'min_child_weight': 8}. Best is trial 11 with value: 0.8894577943416455.
# [I 2025-11-08 20:29:11,424] Trial 18 finished with value: 0.8880965755057965 and parameters: {'n_estimators': 374, 'max_depth': 5, 'learning_rate': 0.12298396053007893, 'subsample': 0.8158517641591019, 'colsample_bytree': 0.9381095799111149, 'gamma': 0.4506688564794985, 'min_child_weight': 6}. Best is trial 11 with value: 0.8894577943416455.
# [I 2025-11-08 20:29:31,977] Trial 19 finished with value: 0.8834433967446271 and parameters: {'n_estimators': 721, 'max_depth': 4, 'learning_rate': 0.05088335592859393, 'subsample': 0.9820206262452034, 'colsample_bytree': 0.9933182344146521, 'gamma': 0.23416880111916855, 'min_child_weight': 2}. Best is trial 11 with value: 0.8894577943416455.
# [I 2025-11-08 20:29:53,626] Trial 20 finished with value: 0.873865453328172 and parameters: {'n_estimators': 657, 'max_depth': 6, 'learning_rate': 0.1903793025026842, 'subsample': 0.9302784615522687, 'colsample_bytree': 0.8990697614370338, 'gamma': 0.42103337665477525, 'min_child_weight': 5}. Best is trial 11 with value: 0.8894577943416455.
# [I 2025-11-08 20:30:11,872] Trial 21 finished with value: 0.8868362833145169 and parameters: {'n_estimators': 565, 'max_depth': 5, 'learning_rate': 0.10590788904086211, 'subsample': 0.7447893506812776, 'colsample_bytree': 0.7157088640186935, 'gamma': 0.3201140893694019, 'min_child_weight': 9}. Best is trial 11 with value: 0.8894577943416455.
# [I 2025-11-08 20:30:34,974] Trial 22 finished with value: 0.8899450146082715 and parameters: {'n_estimators': 743, 'max_depth': 5, 'learning_rate': 0.07496964098925961, 'subsample': 0.9036420765817315, 'colsample_bytree': 0.600038114220701, 'gamma': 0.38405294274137247, 'min_child_weight': 9}. Best is trial 22 with value: 0.8899450146082715.
# [I 2025-11-08 20:30:57,347] Trial 23 finished with value: 0.8763230486276755 and parameters: {'n_estimators': 751, 'max_depth': 4, 'learning_rate': 0.03005521708016648, 'subsample': 0.9018759882942702, 'colsample_bytree': 0.6061766400547881, 'gamma': 0.44398175537058504, 'min_child_weight': 8}. Best is trial 22 with value: 0.8899450146082715.
# [I 2025-11-08 20:31:14,626] Trial 24 finished with value: 0.8801084133433198 and parameters: {'n_estimators': 656, 'max_depth': 3, 'learning_rate': 0.06934653923442756, 'subsample': 0.8583281448010831, 'colsample_bytree': 0.7981583190109179, 'gamma': 0.264668933696511, 'min_child_weight': 9}. Best is trial 22 with value: 0.8899450146082715.
# [I 2025-11-08 20:31:41,488] Trial 25 finished with value: 0.8811929151337297 and parameters: {'n_estimators': 734, 'max_depth': 7, 'learning_rate': 0.08761696923641876, 'subsample': 0.9613735251786998, 'colsample_bytree': 0.9491183709932667, 'gamma': 0.17905981993080128, 'min_child_weight': 6}. Best is trial 22 with value: 0.8899450146082715.
# [I 2025-11-08 20:32:04,894] Trial 26 finished with value: 0.8869476532091345 and parameters: {'n_estimators': 758, 'max_depth': 5, 'learning_rate': 0.126079086319375, 'subsample': 0.9001478301055902, 'colsample_bytree': 0.8406069603201007, 'gamma': 0.3282458967836114, 'min_child_weight': 9}. Best is trial 22 with value: 0.8899450146082715.
# [I 2025-11-08 20:32:25,061] Trial 27 finished with value: 0.8733287116351118 and parameters: {'n_estimators': 674, 'max_depth': 4, 'learning_rate': 0.027868201765893656, 'subsample': 0.822541089848131, 'colsample_bytree': 0.646183419082808, 'gamma': 0.0019219929809730918, 'min_child_weight': 5}. Best is trial 22 with value: 0.8899450146082715.
# [I 2025-11-08 20:32:48,966] Trial 28 finished with value: 0.8892191473370683 and parameters: {'n_estimators': 697, 'max_depth': 6, 'learning_rate': 0.05304284196063472, 'subsample': 0.9201361566527355, 'colsample_bytree': 0.9700132118747946, 'gamma': 0.403421754199553, 'min_child_weight': 8}. Best is trial 22 with value: 0.8899450146082715.
# [I 2025-11-08 20:33:07,654] Trial 29 finished with value: 0.8890632256071593 and parameters: {'n_estimators': 607, 'max_depth': 5, 'learning_rate': 0.09741407189596941, 'subsample': 0.9566049865024274, 'colsample_bytree': 0.7030674101040757, 'gamma': 0.36306400821526996, 'min_child_weight': 2}. Best is trial 22 with value: 0.8899450146082715.
# [I 2025-11-08 20:33:24,588] Trial 30 finished with value: 0.8695160981794752 and parameters: {'n_estimators': 632, 'max_depth': 3, 'learning_rate': 0.03605033231650974, 'subsample': 0.8654130745952338, 'colsample_bytree': 0.859702030228212, 'gamma': 0.4747116189798793, 'min_child_weight': 9}. Best is trial 22 with value: 0.8899450146082715.
# [I 2025-11-08 20:33:42,874] Trial 31 finished with value: 0.8888825237768119 and parameters: {'n_estimators': 545, 'max_depth': 5, 'learning_rate': 0.09302660324966897, 'subsample': 0.6700921233080088, 'colsample_bytree': 0.6337760765797704, 'gamma': 0.371461023075904, 'min_child_weight': 10}. Best is trial 22 with value: 0.8899450146082715.
# [I 2025-11-08 20:34:04,304] Trial 32 finished with value: 0.8892421308883031 and parameters: {'n_estimators': 762, 'max_depth': 4, 'learning_rate': 0.07037450751260925, 'subsample': 0.7484694193590841, 'colsample_bytree': 0.6881504252386862, 'gamma': 0.3375894255450209, 'min_child_weight': 9}. Best is trial 22 with value: 0.8899450146082715.
# [I 2025-11-08 20:34:19,137] Trial 33 finished with value: 0.8841142172312334 and parameters: {'n_estimators': 432, 'max_depth': 6, 'learning_rate': 0.13425462860949822, 'subsample': 0.7961682717165444, 'colsample_bytree': 0.6326303999003555, 'gamma': 0.3964781104032769, 'min_child_weight': 10}. Best is trial 22 with value: 0.8899450146082715.
# [I 2025-11-08 20:34:45,939] Trial 34 finished with value: 0.8686507236926712 and parameters: {'n_estimators': 711, 'max_depth': 7, 'learning_rate': 0.1580911343267329, 'subsample': 0.618174667243276, 'colsample_bytree': 0.6734333870608441, 'gamma': 0.30185751977169123, 'min_child_weight': 7}. Best is trial 22 with value: 0.8899450146082715.
# [I 2025-11-08 20:35:05,336] Trial 35 finished with value: 0.8890000297270733 and parameters: {'n_estimators': 606, 'max_depth': 5, 'learning_rate': 0.08517459146547851, 'subsample': 0.6000822513327272, 'colsample_bytree': 0.917043674048293, 'gamma': 0.22037412004376572, 'min_child_weight': 8}. Best is trial 22 with value: 0.8899450146082715.
# [I 2025-11-08 20:35:19,951] Trial 36 finished with value: 0.8888893642348412 and parameters: {'n_estimators': 492, 'max_depth': 4, 'learning_rate': 0.1087287258026078, 'subsample': 0.6472247285293738, 'colsample_bytree': 0.7790202955034435, 'gamma': 0.26649525614552044, 'min_child_weight': 3}. Best is trial 22 with value: 0.8899450146082715.
# [I 2025-11-08 20:35:44,243] Trial 37 finished with value: 0.8899707769946059 and parameters: {'n_estimators': 764, 'max_depth': 5, 'learning_rate': 0.06967510714121694, 'subsample': 0.8078998193703857, 'colsample_bytree': 0.6207542049266922, 'gamma': 0.35931234625696556, 'min_child_weight': 10}. Best is trial 37 with value: 0.8899707769946059.
# [I 2025-11-08 20:36:08,431] Trial 38 finished with value: 0.8889934671525536 and parameters: {'n_estimators': 765, 'max_depth': 5, 'learning_rate': 0.0659681575167007, 'subsample': 0.7721963932675082, 'colsample_bytree': 0.6229738562385438, 'gamma': 0.3531979502327992, 'min_child_weight': 10}. Best is trial 37 with value: 0.8899707769946059.
# [I 2025-11-08 20:36:28,378] Trial 39 finished with value: 0.8787089015135605 and parameters: {'n_estimators': 675, 'max_depth': 4, 'learning_rate': 0.040007107457535204, 'subsample': 0.8418694889707764, 'colsample_bytree': 0.7488727192412606, 'gamma': 0.43166173930491786, 'min_child_weight': 9}. Best is trial 37 with value: 0.8899707769946059.
# [I 2025-11-08 20:36:54,864] Trial 40 finished with value: 0.8766398293666001 and parameters: {'n_estimators': 799, 'max_depth': 6, 'learning_rate': 0.14386754977742525, 'subsample': 0.8850449063066713, 'colsample_bytree': 0.6480482470340887, 'gamma': 0.14973373125453904, 'min_child_weight': 6}. Best is trial 37 with value: 0.8899707769946059.
# [I 2025-11-08 20:37:16,778] Trial 41 finished with value: 0.8896032695903027 and parameters: {'n_estimators': 694, 'max_depth': 5, 'learning_rate': 0.07878912960957135, 'subsample': 0.8158464763779548, 'colsample_bytree': 0.6165346510769966, 'gamma': 0.37544897545564915, 'min_child_weight': 10}. Best is trial 37 with value: 0.8899707769946059.
# [I 2025-11-08 20:37:40,405] Trial 42 finished with value: 0.8907202546705432 and parameters: {'n_estimators': 743, 'max_depth': 5, 'learning_rate': 0.07662531300380107, 'subsample': 0.8026500715550352, 'colsample_bytree': 0.6002985430277121, 'gamma': 0.30577919189570324, 'min_child_weight': 10}. Best is trial 42 with value: 0.8907202546705432.
# [I 2025-11-08 20:38:00,574] Trial 43 finished with value: 0.8895430851919754 and parameters: {'n_estimators': 689, 'max_depth': 4, 'learning_rate': 0.1011509463683847, 'subsample': 0.8061596484574649, 'colsample_bytree': 0.6009521778402785, 'gamma': 0.3061109613785004, 'min_child_weight': 10}. Best is trial 42 with value: 0.8907202546705432.
# [I 2025-11-08 20:38:20,828] Trial 44 finished with value: 0.8886733873547494 and parameters: {'n_estimators': 634, 'max_depth': 5, 'learning_rate': 0.08575525370293766, 'subsample': 0.769562407685556, 'colsample_bytree': 0.612686762520361, 'gamma': 0.38242486379388946, 'min_child_weight': 10}. Best is trial 42 with value: 0.8907202546705432.
# [I 2025-11-08 20:38:50,983] Trial 45 finished with value: 0.8729793474390448 and parameters: {'n_estimators': 692, 'max_depth': 9, 'learning_rate': 0.10134722568835214, 'subsample': 0.7206653278004228, 'colsample_bytree': 0.6570487574250209, 'gamma': 0.3500878166696811, 'min_child_weight': 10}. Best is trial 42 with value: 0.8907202546705432.
# [I 2025-11-08 20:39:15,296] Trial 46 finished with value: 0.8883991486424745 and parameters: {'n_estimators': 690, 'max_depth': 6, 'learning_rate': 0.0805510133796504, 'subsample': 0.8103135752516852, 'colsample_bytree': 0.6014824651401031, 'gamma': 0.30548970973387674, 'min_child_weight': 10}. Best is trial 42 with value: 0.8907202546705432.
# [I 2025-11-08 20:39:37,489] Trial 47 finished with value: 0.8883829990868619 and parameters: {'n_estimators': 778, 'max_depth': 4, 'learning_rate': 0.11262745783894225, 'subsample': 0.7865360935578715, 'colsample_bytree': 0.6240347012680101, 'gamma': 0.4104434163192635, 'min_child_weight': 9}. Best is trial 42 with value: 0.8907202546705432.
# [I 2025-11-08 20:39:56,902] Trial 48 finished with value: 0.8797379396941083 and parameters: {'n_estimators': 736, 'max_depth': 3, 'learning_rate': 0.059417034857971396, 'subsample': 0.758064544294726, 'colsample_bytree': 0.690575568659941, 'gamma': 0.3832906081696685, 'min_child_weight': 10}. Best is trial 42 with value: 0.8907202546705432.
# [I 2025-11-08 20:40:09,464] Trial 49 finished with value: 0.8730090809746086 and parameters: {'n_estimators': 316, 'max_depth': 7, 'learning_rate': 0.24032648656341232, 'subsample': 0.7191435569344002, 'colsample_bytree': 0.6422793258678058, 'gamma': 0.31481372378658523, 'min_child_weight': 10}. Best is trial 42 with value: 0.8907202546705432.
# Best params: {'n_estimators': 743, 'max_depth': 5, 'learning_rate': 0.07662531300380107, 'subsample': 0.8026500715550352, 'colsample_bytree': 0.6002985430277121, 'gamma': 0.30577919189570324, 'min_child_weight': 10}
# Best AUC: 0.8907202546705432

# %%
# Extract best parameters
best_params = study.best_params  # from your Optuna study

# Optional: add fixed parameters
best_params.update({
    "eval_metric": "auc",
    "random_state": 42,
    "n_jobs": -1
})

# Train best model on training set
final_model = XGBClassifier(**best_params)
final_model.fit(X_train_resampled_log, y_train_resampled.values.ravel())
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6002985430277121, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='auc', feature_types=None, feature_weights=None,
#               gamma=0.30577919189570324, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.07662531300380107,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=10, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=743, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %%
# Evaluate final model on train set
y_train_final_pred = final_model.predict(X_train_resampled_log)
y_train_final_proba = final_model.predict_proba(X_train_resampled_log)[:, 1]

# classification report
print("Final Model Training Classification Report:\n")
print(classification_report(y_train_resampled, y_train_final_pred, digits=4))

# roc auc
roc_auc_train_final = roc_auc_score(y_train_resampled, y_train_final_proba)
print(f"Final Model Training ROC-AUC Score: {roc_auc_train_final:.4f}")

# pr auc
pr_auc_train_final = average_precision_score(y_train_resampled, y_train_final_proba)
print(f"Final Model Training PR-AUC Score: {pr_auc_train_final:.4f}")

# confusion matrix
print("Final Model Training Confusion Matrix:\n", confusion_matrix(y_train_resampled, y_train_final_pred))
# Out:
# Final Model Training Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9902    0.9995    0.9948    786838
#            1     0.9995    0.9901    0.9948    786838
#
#     accuracy                         0.9948   1573676
#    macro avg     0.9949    0.9948    0.9948   1573676
# weighted avg     0.9949    0.9948    0.9948   1573676
#
# Final Model Training ROC-AUC Score: 0.9993
# Final Model Training PR-AUC Score: 0.9994
# Final Model Training Confusion Matrix:
#  [[786453    385]
#  [  7779 779059]]

# %%
# Evaluate final model on validation set
y_val_final_pred = final_model.predict(X_val_log)
y_val_final_proba = final_model.predict_proba(X_val_log)[:, 1]

# classification report
print("\nFinal Model Validation Classification Report:\n")
print(classification_report(y_val, y_val_final_pred, digits=4))

# roc auc
roc_auc_val_final = roc_auc_score(y_val, y_val_final_proba)
print(f"Final Model Validation ROC-AUC Score: {roc_auc_val_final:.4f}")

# pr auc
pr_auc_val_final = average_precision_score(y_val, y_val_final_proba)
print(f"Final Model Validation PR-AUC Score: {pr_auc_val_final:.4f}")

# confusion matrix
print("Final Model Validation Confusion Matrix:\n", confusion_matrix(y_val, y_val_final_pred))
# Out:
# Final Model Validation Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9875    0.9985    0.9929    106718
#            1     0.3731    0.0669    0.1135      1450
#
#     accuracy                         0.9860    108168
#    macro avg     0.6803    0.5327    0.5532    108168
# weighted avg     0.9792    0.9860    0.9811    108168
#
# Final Model Validation ROC-AUC Score: 0.8907
# Final Model Validation PR-AUC Score: 0.1650
# Final Model Validation Confusion Matrix:
#  [[106555    163]
#  [  1353     97]]

# %%
# Evaluate on Test Set
y_test_pred = xgb_baseline.predict(X_test_log)
y_test_proba = xgb_baseline.predict_proba(X_test_log)[:, 1]
# Classification report
print("\nTest Classification Report:\n")
print(classification_report(y_test, y_test_pred, digits=4))
# ROC-AUC
roc_auc_test = roc_auc_score(y_test, y_test_proba)
print(f"Test ROC-AUC Score: {roc_auc_test:.4f}")
# PR-AUC
pr_auc_test = average_precision_score(y_test, y_test_proba)
print(f"Test PR-AUC Score: {pr_auc_test:.4f}")
# Confusion matrix
print("Test Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred))
# Out:
# Test Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9864    0.9985    0.9924     95415
#            1     0.4406    0.0805    0.1362      1428
#
#     accuracy                         0.9849     96843
#    macro avg     0.7135    0.5395    0.5643     96843
# weighted avg     0.9784    0.9849    0.9798     96843
#
# Test ROC-AUC Score: 0.8729
# Test PR-AUC Score: 0.1768
# Test Confusion Matrix:
#  [[95269   146]
#  [ 1313   115]]

# %% [markdown]
# ## Use original train with class weighting

# %% [markdown]
# ### Baseline

# %%
# Extract 1D labels
y = y_train['fraud_bool'].values

# Compute class weight correctly
pos = (y == 1).sum()
neg = (y == 0).sum()
scale = neg / pos

# Baseline XGBoost model
xgb_baseline = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.2,
    eval_metric='auc',
    random_state=42,
    scale_pos_weight=scale,   # float, not Series
    n_jobs=-1
)

# Fit
xgb_baseline.fit(X_train_log, y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.2, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=300,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %%
# Evaluate on Train Set
y_train_pred = xgb_baseline.predict(X_train_log)
y_train_proba = xgb_baseline.predict_proba(X_train_log)[:, 1]

# Classification report
print("Training Classification Report:\n")
print(classification_report(y_train, y_train_pred, digits=4))

# ROC-AUC
roc_auc_train = roc_auc_score(y_train, y_train_proba)
print(f"Training ROC-AUC Score: {roc_auc_train:.4f}")

# PR-AUC
pr_auc_train = average_precision_score(y_train, y_train_proba)
print(f"Training PR-AUC Score: {pr_auc_train:.4f}")

# Confusion matrix
print("Training Confusion Matrix:\n", confusion_matrix(y_train, y_train_pred))
# Out:
# Training Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9999    0.9233    0.9600    786838
#            1     0.1177    0.9879    0.2103      8151
#
#     accuracy                         0.9239    794989
#    macro avg     0.5588    0.9556    0.5851    794989
# weighted avg     0.9908    0.9239    0.9523    794989
#
# Training ROC-AUC Score: 0.9869
# Training PR-AUC Score: 0.4345
# Training Confusion Matrix:
#  [[726450  60388]
#  [    99   8052]]

# %%
# Evaluate on Validation Set
y_val_pred = xgb_baseline.predict(X_val_log)
y_val_proba = xgb_baseline.predict_proba(X_val_log)[:, 1]  

# Classification report
print("\nValidation Classification Report:\n")
print(classification_report(y_val, y_val_pred, digits=4))

# ROC-AUC
roc_auc_val = roc_auc_score(y_val, y_val_proba)
print(f"Validation ROC-AUC Score: {roc_auc_val:.4f}")

# PR-AUC
pr_auc_val = average_precision_score(y_val, y_val_proba)
print(f"Validation PR-AUC Score: {pr_auc_val:.4f}")

# Confusion matrix
print("Validation Confusion Matrix:\n", confusion_matrix(y_val, y_val_pred))
# Out:
# Validation Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9942    0.9020    0.9459    106718
#            1     0.0786    0.6152    0.1394      1450
#
#     accuracy                         0.8982    108168
#    macro avg     0.5364    0.7586    0.5426    108168
# weighted avg     0.9820    0.8982    0.9351    108168
#
# Validation ROC-AUC Score: 0.8667
# Validation PR-AUC Score: 0.1508
# Validation Confusion Matrix:
#  [[96262 10456]
#  [  558   892]]

# %%
# Evaluate on Test Set
y_test_pred = xgb_baseline.predict(X_test_log)
y_test_proba = xgb_baseline.predict_proba(X_test_log)[:, 1]
# Classification report
print("\nTest Classification Report:\n")
print(classification_report(y_test, y_test_pred, digits=4))
# ROC-AUC
roc_auc_test = roc_auc_score(y_test, y_test_proba)
print(f"Test ROC-AUC Score: {roc_auc_test:.4f}")
# PR-AUC
pr_auc_test = average_precision_score(y_test, y_test_proba)
print(f"Test PR-AUC Score: {pr_auc_test:.4f}")
# Confusion matrix
print("Test Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred))
# Out:
# Test Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9912    0.9489    0.9696     95415
#            1     0.1136    0.4370    0.1803      1428
#
#     accuracy                         0.9414     96843
#    macro avg     0.5524    0.6930    0.5749     96843
# weighted avg     0.9783    0.9414    0.9580     96843
#
# Test ROC-AUC Score: 0.8431
# Test PR-AUC Score: 0.1375
# Test Confusion Matrix:
#  [[90544  4871]
#  [  804   624]]

# %% [markdown]
# ### Hyperparameter Tuning

# %%
import optuna
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score

def objective(trial):

    # Suggest hyperparameters
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 200, 800),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 5),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 20),
        
        # Tune scale_pos_weight around the base imbalance ratio
        "scale_pos_weight": trial.suggest_float(
            "scale_pos_weight", 
            scale * 0.5, 
            scale * 2.0
        ),

        "early_stopping_rounds": 50,
        "eval_metric": "auc",
        "random_state": 42,
        "n_jobs": -1,
    }

    model = XGBClassifier(**params)

    model.fit(
        X_train_log, 
        y,
        eval_set=[(X_val_log, y_val)],
        verbose=False
    )

    # Predict on validation
    preds = model.predict_proba(X_val_log)[:, 1]
    auc = roc_auc_score(y_val, preds)

    return auc

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)
print("Best params:", study.best_params)
# Out:
# [I 2025-11-08 20:45:37,609] A new study created in memory with name: no-name-ebf09814-34ad-4a3d-a1e3-956f2401cdc4
# [I 2025-11-08 20:45:40,394] Trial 0 finished with value: 0.890139953121698 and parameters: {'n_estimators': 606, 'max_depth': 4, 'learning_rate': 0.29291565992410284, 'subsample': 0.7101386627897796, 'colsample_bytree': 0.9898785308832807, 'gamma': 2.4134734661688912, 'min_child_weight': 17, 'scale_pos_weight': 174.7533526696692}. Best is trial 0 with value: 0.890139953121698.
# [I 2025-11-08 20:45:47,309] Trial 1 finished with value: 0.8769869478761622 and parameters: {'n_estimators': 367, 'max_depth': 10, 'learning_rate': 0.036322949663834286, 'subsample': 0.8196392526966025, 'colsample_bytree': 0.9910628179757812, 'gamma': 3.297344245092242, 'min_child_weight': 18, 'scale_pos_weight': 142.83252613812937}. Best is trial 0 with value: 0.890139953121698.
# [I 2025-11-08 20:45:59,679] Trial 2 finished with value: 0.8927052185876925 and parameters: {'n_estimators': 605, 'max_depth': 4, 'learning_rate': 0.025168869678722214, 'subsample': 0.9957472310041323, 'colsample_bytree': 0.9201150670486651, 'gamma': 2.7828934405659074, 'min_child_weight': 9, 'scale_pos_weight': 149.59264073204696}. Best is trial 2 with value: 0.8927052185876925.
# [I 2025-11-08 20:46:03,966] Trial 3 finished with value: 0.8751969644780863 and parameters: {'n_estimators': 693, 'max_depth': 9, 'learning_rate': 0.08466001688117987, 'subsample': 0.6965717252739015, 'colsample_bytree': 0.9360018618300204, 'gamma': 2.6549854928962806, 'min_child_weight': 3, 'scale_pos_weight': 110.58003486013509}. Best is trial 2 with value: 0.8927052185876925.
# [I 2025-11-08 20:46:11,363] Trial 4 finished with value: 0.8943759511855609 and parameters: {'n_estimators': 405, 'max_depth': 4, 'learning_rate': 0.07990132354284188, 'subsample': 0.7511704481418635, 'colsample_bytree': 0.6901793094429023, 'gamma': 2.4335502130590063, 'min_child_weight': 6, 'scale_pos_weight': 90.19825411887125}. Best is trial 4 with value: 0.8943759511855609.
# [I 2025-11-08 20:46:14,795] Trial 5 finished with value: 0.8892726108318992 and parameters: {'n_estimators': 699, 'max_depth': 4, 'learning_rate': 0.20862941848375274, 'subsample': 0.7059987468684451, 'colsample_bytree': 0.8376369967779687, 'gamma': 1.8500501096465922, 'min_child_weight': 10, 'scale_pos_weight': 189.3870079945449}. Best is trial 4 with value: 0.8943759511855609.
# [I 2025-11-08 20:46:18,382] Trial 6 finished with value: 0.8855759361927762 and parameters: {'n_estimators': 715, 'max_depth': 7, 'learning_rate': 0.14158654259005446, 'subsample': 0.760201607088093, 'colsample_bytree': 0.7377167187237845, 'gamma': 2.0330353216487316, 'min_child_weight': 3, 'scale_pos_weight': 63.50462797711198}. Best is trial 4 with value: 0.8943759511855609.
# [I 2025-11-08 20:46:27,568] Trial 7 finished with value: 0.8916770689881356 and parameters: {'n_estimators': 434, 'max_depth': 4, 'learning_rate': 0.0247898576908212, 'subsample': 0.7734750711231453, 'colsample_bytree': 0.8698529472271666, 'gamma': 1.0088378385519836, 'min_child_weight': 19, 'scale_pos_weight': 174.99070803136152}. Best is trial 4 with value: 0.8943759511855609.
# [I 2025-11-08 20:46:30,993] Trial 8 finished with value: 0.8909642977851391 and parameters: {'n_estimators': 610, 'max_depth': 4, 'learning_rate': 0.18094384367156371, 'subsample': 0.6316804030377855, 'colsample_bytree': 0.8991045247755081, 'gamma': 0.9659606801805903, 'min_child_weight': 5, 'scale_pos_weight': 88.62704838177687}. Best is trial 4 with value: 0.8943759511855609.
# [I 2025-11-08 20:46:33,857] Trial 9 finished with value: 0.8726073066560857 and parameters: {'n_estimators': 284, 'max_depth': 9, 'learning_rate': 0.18012595262920855, 'subsample': 0.7930855708941431, 'colsample_bytree': 0.7077231026180564, 'gamma': 4.850259191583345, 'min_child_weight': 16, 'scale_pos_weight': 191.03688358542522}. Best is trial 4 with value: 0.8943759511855609.
# [I 2025-11-08 20:46:39,710] Trial 10 finished with value: 0.8916030194951438 and parameters: {'n_estimators': 228, 'max_depth': 6, 'learning_rate': 0.06556294526656012, 'subsample': 0.8885414763571455, 'colsample_bytree': 0.6575719904358266, 'gamma': 4.000546529028789, 'min_child_weight': 7, 'scale_pos_weight': 49.632850662307746}. Best is trial 4 with value: 0.8943759511855609.
# [I 2025-11-08 20:46:52,892] Trial 11 finished with value: 0.8885584146681133 and parameters: {'n_estimators': 521, 'max_depth': 6, 'learning_rate': 0.011834240728538203, 'subsample': 0.9896459481536414, 'colsample_bytree': 0.611269412332178, 'gamma': 0.007516326145566854, 'min_child_weight': 10, 'scale_pos_weight': 137.5236060857972}. Best is trial 4 with value: 0.8943759511855609.
# [I 2025-11-08 20:47:02,562] Trial 12 finished with value: 0.8896470750175616 and parameters: {'n_estimators': 516, 'max_depth': 3, 'learning_rate': 0.02354965105792917, 'subsample': 0.9656392120092839, 'colsample_bytree': 0.7761825738734589, 'gamma': 3.262445259660759, 'min_child_weight': 14, 'scale_pos_weight': 100.96002462552067}. Best is trial 4 with value: 0.8943759511855609.
# [I 2025-11-08 20:47:11,509] Trial 13 finished with value: 0.8927596675996229 and parameters: {'n_estimators': 391, 'max_depth': 5, 'learning_rate': 0.04281092960783451, 'subsample': 0.8865262770498048, 'colsample_bytree': 0.8060977451948125, 'gamma': 3.2837615201284587, 'min_child_weight': 7, 'scale_pos_weight': 138.49470428478384}. Best is trial 4 with value: 0.8943759511855609.
# [I 2025-11-08 20:47:15,723] Trial 14 finished with value: 0.8862185353471056 and parameters: {'n_estimators': 355, 'max_depth': 7, 'learning_rate': 0.10099663819898266, 'subsample': 0.8849487757017858, 'colsample_bytree': 0.79546400796547, 'gamma': 4.056645697407058, 'min_child_weight': 13, 'scale_pos_weight': 79.00318219940208}. Best is trial 4 with value: 0.8943759511855609.
# [I 2025-11-08 20:47:24,451] Trial 15 finished with value: 0.8933647169368707 and parameters: {'n_estimators': 424, 'max_depth': 5, 'learning_rate': 0.045005861082954964, 'subsample': 0.8669396515747622, 'colsample_bytree': 0.7078831535114483, 'gamma': 3.693339371426272, 'min_child_weight': 1, 'scale_pos_weight': 123.43487323401945}. Best is trial 4 with value: 0.8943759511855609.
# [I 2025-11-08 20:47:33,539] Trial 16 finished with value: 0.8939106384793697 and parameters: {'n_estimators': 467, 'max_depth': 3, 'learning_rate': 0.05006926827076326, 'subsample': 0.8403659829609348, 'colsample_bytree': 0.6862934655724819, 'gamma': 4.594889825873071, 'min_child_weight': 1, 'scale_pos_weight': 119.06722997933382}. Best is trial 4 with value: 0.8943759511855609.
# [I 2025-11-08 20:47:40,468] Trial 17 finished with value: 0.8937602905756775 and parameters: {'n_estimators': 473, 'max_depth': 3, 'learning_rate': 0.06801883550579695, 'subsample': 0.6027893979276895, 'colsample_bytree': 0.6357033269908827, 'gamma': 4.989696813977024, 'min_child_weight': 1, 'scale_pos_weight': 84.39608951374036}. Best is trial 4 with value: 0.8943759511855609.
# [I 2025-11-08 20:47:46,147] Trial 18 finished with value: 0.8941481901059252 and parameters: {'n_estimators': 281, 'max_depth': 3, 'learning_rate': 0.09662709659246994, 'subsample': 0.8321789391001421, 'colsample_bytree': 0.6774972954036091, 'gamma': 1.4621209998163018, 'min_child_weight': 5, 'scale_pos_weight': 119.67069712535358}. Best is trial 4 with value: 0.8943759511855609.
# [I 2025-11-08 20:47:50,476] Trial 19 finished with value: 0.8914567105959567 and parameters: {'n_estimators': 266, 'max_depth': 5, 'learning_rate': 0.11394865735260698, 'subsample': 0.7435338284157931, 'colsample_bytree': 0.7364128660687665, 'gamma': 1.327512549337641, 'min_child_weight': 7, 'scale_pos_weight': 102.38293928316037}. Best is trial 4 with value: 0.8943759511855609.
# [I 2025-11-08 20:47:56,937] Trial 20 finished with value: 0.8947748497328764 and parameters: {'n_estimators': 327, 'max_depth': 3, 'learning_rate': 0.08915609014053351, 'subsample': 0.9338839970273081, 'colsample_bytree': 0.6048395926392132, 'gamma': 0.20770129311574248, 'min_child_weight': 5, 'scale_pos_weight': 74.3417725383331}. Best is trial 20 with value: 0.8947748497328764.
# [I 2025-11-08 20:48:03,025] Trial 21 finished with value: 0.8935990922902838 and parameters: {'n_estimators': 311, 'max_depth': 3, 'learning_rate': 0.07674407417894995, 'subsample': 0.9341211157432872, 'colsample_bytree': 0.6120696981057182, 'gamma': 0.22309929683100638, 'min_child_weight': 5, 'scale_pos_weight': 72.17553956857981}. Best is trial 20 with value: 0.8947748497328764.
# [I 2025-11-08 20:48:07,133] Trial 22 finished with value: 0.8939488506931901 and parameters: {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.11017630883533784, 'subsample': 0.9234974318453275, 'colsample_bytree': 0.6614499902569525, 'gamma': 0.4248050261434174, 'min_child_weight': 5, 'scale_pos_weight': 60.5474244950031}. Best is trial 20 with value: 0.8947748497328764.
# [I 2025-11-08 20:48:11,275] Trial 23 finished with value: 0.8910286795169481 and parameters: {'n_estimators': 325, 'max_depth': 5, 'learning_rate': 0.1394076726367928, 'subsample': 0.8300120510773582, 'colsample_bytree': 0.6023347614232928, 'gamma': 1.396846183040417, 'min_child_weight': 8, 'scale_pos_weight': 89.07926348464503}. Best is trial 20 with value: 0.8947748497328764.
# [I 2025-11-08 20:48:16,494] Trial 24 finished with value: 0.8915465897554044 and parameters: {'n_estimators': 263, 'max_depth': 3, 'learning_rate': 0.061563036481680614, 'subsample': 0.9222309973084534, 'colsample_bytree': 0.6513491053588839, 'gamma': 0.6900490952612208, 'min_child_weight': 3, 'scale_pos_weight': 99.76429369163421}. Best is trial 20 with value: 0.8947748497328764.
# [I 2025-11-08 20:48:23,166] Trial 25 finished with value: 0.8945180465952485 and parameters: {'n_estimators': 324, 'max_depth': 4, 'learning_rate': 0.0893177064383623, 'subsample': 0.7391152995615314, 'colsample_bytree': 0.689291058941807, 'gamma': 1.8224750959808749, 'min_child_weight': 12, 'scale_pos_weight': 71.90767444512943}. Best is trial 20 with value: 0.8947748497328764.
# [I 2025-11-08 20:48:32,678] Trial 26 finished with value: 0.8922451985930048 and parameters: {'n_estimators': 392, 'max_depth': 6, 'learning_rate': 0.03451575043678652, 'subsample': 0.6634309877491632, 'colsample_bytree': 0.7435165502712698, 'gamma': 2.019218711516956, 'min_child_weight': 12, 'scale_pos_weight': 50.1229572311521}. Best is trial 20 with value: 0.8947748497328764.
# [I 2025-11-08 20:48:40,145] Trial 27 finished with value: 0.8804602784909762 and parameters: {'n_estimators': 340, 'max_depth': 4, 'learning_rate': 0.011998033607919517, 'subsample': 0.7337028294132094, 'colsample_bytree': 0.706384042065854, 'gamma': 2.2657368239233375, 'min_child_weight': 11, 'scale_pos_weight': 72.4954193002181}. Best is trial 20 with value: 0.8947748497328764.
# [I 2025-11-08 20:48:44,610] Trial 28 finished with value: 0.8872043658730615 and parameters: {'n_estimators': 551, 'max_depth': 8, 'learning_rate': 0.07827542386159785, 'subsample': 0.7832791882950041, 'colsample_bytree': 0.6326853806767153, 'gamma': 1.6852371034722782, 'min_child_weight': 15, 'scale_pos_weight': 61.42550153580572}. Best is trial 20 with value: 0.8947748497328764.
# [I 2025-11-08 20:48:47,032] Trial 29 finished with value: 0.8850172513960415 and parameters: {'n_estimators': 428, 'max_depth': 5, 'learning_rate': 0.2816936105161936, 'subsample': 0.68299004924133, 'colsample_bytree': 0.7624223275573037, 'gamma': 2.8592980440098343, 'min_child_weight': 12, 'scale_pos_weight': 73.66690009841618}. Best is trial 20 with value: 0.8947748497328764.
# [I 2025-11-08 20:48:52,180] Trial 30 finished with value: 0.8934395645371526 and parameters: {'n_estimators': 794, 'max_depth': 4, 'learning_rate': 0.13047629574088992, 'subsample': 0.722962210654419, 'colsample_bytree': 0.6287778994330302, 'gamma': 2.3076130268374495, 'min_child_weight': 8, 'scale_pos_weight': 88.78775709319878}. Best is trial 20 with value: 0.8947748497328764.
# [I 2025-11-08 20:48:58,031] Trial 31 finished with value: 0.8949283125168426 and parameters: {'n_estimators': 294, 'max_depth': 3, 'learning_rate': 0.09315320452369848, 'subsample': 0.7565807206346981, 'colsample_bytree': 0.6825077723092992, 'gamma': 1.4957570716034694, 'min_child_weight': 4, 'scale_pos_weight': 115.61355973727945}. Best is trial 31 with value: 0.8949283125168426.
# [I 2025-11-08 20:49:06,027] Trial 32 finished with value: 0.8938861007192014 and parameters: {'n_estimators': 374, 'max_depth': 4, 'learning_rate': 0.06083789390776315, 'subsample': 0.7582575184839719, 'colsample_bytree': 0.685709350762817, 'gamma': 1.0089396496369232, 'min_child_weight': 4, 'scale_pos_weight': 109.60227896314484}. Best is trial 31 with value: 0.8949283125168426.
# [I 2025-11-08 20:49:12,291] Trial 33 finished with value: 0.8939147582639648 and parameters: {'n_estimators': 312, 'max_depth': 3, 'learning_rate': 0.09013948797513366, 'subsample': 0.6669218660308392, 'colsample_bytree': 0.710762652629203, 'gamma': 0.5709627296358828, 'min_child_weight': 9, 'scale_pos_weight': 96.5409602761565}. Best is trial 31 with value: 0.8949283125168426.
# [I 2025-11-08 20:49:17,733] Trial 34 finished with value: 0.8919392391549498 and parameters: {'n_estimators': 243, 'max_depth': 4, 'learning_rate': 0.052518700480381264, 'subsample': 0.8088540811225717, 'colsample_bytree': 0.6675931718817191, 'gamma': 2.504676884288816, 'min_child_weight': 6, 'scale_pos_weight': 129.34818174132124}. Best is trial 31 with value: 0.8949283125168426.
# [I 2025-11-08 20:49:25,418] Trial 35 finished with value: 0.8928143331021946 and parameters: {'n_estimators': 354, 'max_depth': 4, 'learning_rate': 0.03511243493749363, 'subsample': 0.7152996215446227, 'colsample_bytree': 0.7274631763313845, 'gamma': 3.029222938302774, 'min_child_weight': 2, 'scale_pos_weight': 110.43779415602344}. Best is trial 31 with value: 0.8949283125168426.
# [I 2025-11-08 20:49:28,621] Trial 36 finished with value: 0.8900225408763413 and parameters: {'n_estimators': 302, 'max_depth': 5, 'learning_rate': 0.1650492075047617, 'subsample': 0.7520705608473072, 'colsample_bytree': 0.9507187665338372, 'gamma': 1.7011288808022094, 'min_child_weight': 4, 'scale_pos_weight': 64.93091781938459}. Best is trial 31 with value: 0.8949283125168426.
# [I 2025-11-08 20:49:32,629] Trial 37 finished with value: 0.8711380331405167 and parameters: {'n_estimators': 395, 'max_depth': 10, 'learning_rate': 0.07760260958907926, 'subsample': 0.8009132305620352, 'colsample_bytree': 0.7653898202787806, 'gamma': 1.919755875374539, 'min_child_weight': 9, 'scale_pos_weight': 154.10494049192607}. Best is trial 31 with value: 0.8949283125168426.
# [I 2025-11-08 20:49:36,248] Trial 38 finished with value: 0.8902414872325451 and parameters: {'n_estimators': 202, 'max_depth': 4, 'learning_rate': 0.23966983603453101, 'subsample': 0.6933442476180823, 'colsample_bytree': 0.6925589554588476, 'gamma': 1.197813544498885, 'min_child_weight': 17, 'scale_pos_weight': 80.09968642590196}. Best is trial 31 with value: 0.8949283125168426.
# [I 2025-11-08 20:49:41,872] Trial 39 finished with value: 0.8932773807346595 and parameters: {'n_estimators': 441, 'max_depth': 3, 'learning_rate': 0.1220810656888833, 'subsample': 0.7720045098314048, 'colsample_bytree': 0.6300938581647427, 'gamma': 2.1633226943761974, 'min_child_weight': 3, 'scale_pos_weight': 160.0304694188921}. Best is trial 31 with value: 0.8949283125168426.
# [I 2025-11-08 20:49:45,582] Trial 40 finished with value: 0.8931979900621102 and parameters: {'n_estimators': 344, 'max_depth': 4, 'learning_rate': 0.14827687731483716, 'subsample': 0.7282995926329188, 'colsample_bytree': 0.8278882748995835, 'gamma': 2.6531877648634175, 'min_child_weight': 6, 'scale_pos_weight': 94.99561234099068}. Best is trial 31 with value: 0.8949283125168426.
# [I 2025-11-08 20:49:50,972] Trial 41 finished with value: 0.8943078406447931 and parameters: {'n_estimators': 278, 'max_depth': 3, 'learning_rate': 0.09455581576286905, 'subsample': 0.8425031589340233, 'colsample_bytree': 0.6627212310506856, 'gamma': 1.5214145610947667, 'min_child_weight': 4, 'scale_pos_weight': 118.38905106123482}. Best is trial 31 with value: 0.8949283125168426.
# [I 2025-11-08 20:49:55,773] Trial 42 finished with value: 0.8934366758411308 and parameters: {'n_estimators': 241, 'max_depth': 3, 'learning_rate': 0.08544550068772659, 'subsample': 0.7768904937212565, 'colsample_bytree': 0.6423639708269322, 'gamma': 1.6362751946378147, 'min_child_weight': 4, 'scale_pos_weight': 112.63982720950554}. Best is trial 31 with value: 0.8949283125168426.
# [I 2025-11-08 20:50:01,363] Trial 43 finished with value: 0.8942813577000551 and parameters: {'n_estimators': 287, 'max_depth': 3, 'learning_rate': 0.1040616700108545, 'subsample': 0.9486780720147825, 'colsample_bytree': 0.6571168321199828, 'gamma': 0.8153387117100868, 'min_child_weight': 6, 'scale_pos_weight': 130.6770419973944}. Best is trial 31 with value: 0.8949283125168426.
# [I 2025-11-08 20:50:07,408] Trial 44 finished with value: 0.8938199741374463 and parameters: {'n_estimators': 325, 'max_depth': 4, 'learning_rate': 0.06912340129809873, 'subsample': 0.8580684919776641, 'colsample_bytree': 0.6006472963030848, 'gamma': 1.168954728630481, 'min_child_weight': 2, 'scale_pos_weight': 106.70377495058048}. Best is trial 31 with value: 0.8949283125168426.
# [I 2025-11-08 20:50:14,168] Trial 45 finished with value: 0.8947748626576908 and parameters: {'n_estimators': 372, 'max_depth': 3, 'learning_rate': 0.09226007906982722, 'subsample': 0.8083742302581227, 'colsample_bytree': 0.7224191033114239, 'gamma': 1.9087126039392717, 'min_child_weight': 20, 'scale_pos_weight': 67.65416953402607}. Best is trial 31 with value: 0.8949283125168426.
# [I 2025-11-08 20:50:18,989] Trial 46 finished with value: 0.8939971410310511 and parameters: {'n_estimators': 406, 'max_depth': 4, 'learning_rate': 0.15958822320740526, 'subsample': 0.7070313635090167, 'colsample_bytree': 0.7257347003553021, 'gamma': 1.815209027050169, 'min_child_weight': 14, 'scale_pos_weight': 58.97003429176168}. Best is trial 31 with value: 0.8949283125168426.
# [I 2025-11-08 20:50:26,473] Trial 47 finished with value: 0.8935481265158385 and parameters: {'n_estimators': 371, 'max_depth': 6, 'learning_rate': 0.054779136723952085, 'subsample': 0.8112419928391419, 'colsample_bytree': 0.750132941493075, 'gamma': 2.6195983738884188, 'min_child_weight': 18, 'scale_pos_weight': 67.24836086173552}. Best is trial 31 with value: 0.8949283125168426.
# [I 2025-11-08 20:50:30,130] Trial 48 finished with value: 0.8907453191168991 and parameters: {'n_estimators': 478, 'max_depth': 5, 'learning_rate': 0.18957231208780695, 'subsample': 0.7462758085079501, 'colsample_bytree': 0.7795961808996053, 'gamma': 3.0067711246887594, 'min_child_weight': 19, 'scale_pos_weight': 78.73026389808983}. Best is trial 31 with value: 0.8949283125168426.
# [I 2025-11-08 20:50:33,685] Trial 49 finished with value: 0.8857645060038996 and parameters: {'n_estimators': 577, 'max_depth': 8, 'learning_rate': 0.12480439519881982, 'subsample': 0.9828246130358288, 'colsample_bytree': 0.6980236885302473, 'gamma': 2.107362457079108, 'min_child_weight': 20, 'scale_pos_weight': 51.48856013086373}. Best is trial 31 with value: 0.8949283125168426.
# Best params: {'n_estimators': 294, 'max_depth': 3, 'learning_rate': 0.09315320452369848, 'subsample': 0.7565807206346981, 'colsample_bytree': 0.6825077723092992, 'gamma': 1.4957570716034694, 'min_child_weight': 4, 'scale_pos_weight': 115.61355973727945}

# %%
# Extract best parameters
best_params = study.best_params  # from Optuna study

# Train final model on full training set
final_model = XGBClassifier(**best_params)
final_model.fit(X_train_log, y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6825077723092992, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, feature_weights=None,
#               gamma=1.4957570716034694, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.09315320452369848,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=4, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=294, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
# Evaluate on Train Set
y_train_pred = final_model.predict(X_train_log)
y_train_proba = final_model.predict_proba(X_train_log)[:, 1]

# Classification report
print("Final Model Training Classification Report:\n")
print(classification_report(y_train, y_train_pred, digits=4))

# ROC-AUC
roc_auc_train = roc_auc_score(y_train, y_train_proba)
print(f"Final Model Training ROC-AUC Score: {roc_auc_train:.4f}")

# PR-AUC
pr_auc_train = average_precision_score(y_train, y_train_proba)
print(f"Final Model Training PR-AUC Score: {pr_auc_train:.4f}") 

# Confusion matrix
print("Final Model Training Confusion Matrix:\n", confusion_matrix(y_train, y_train_pred))
# Out:
# Final Model Training Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9982    0.8062    0.8920    786838
#            1     0.0440    0.8620    0.0838      8151
#
#     accuracy                         0.8067    794989
#    macro avg     0.5211    0.8341    0.4879    794989
# weighted avg     0.9884    0.8067    0.8837    794989
#
# Final Model Training ROC-AUC Score: 0.9134
# Final Model Training PR-AUC Score: 0.1775
# Final Model Training Confusion Matrix:
#  [[634326 152512]
#  [  1125   7026]]

# %%
# Evaluate on Validation Set
y_val_pred = final_model.predict(X_val_log)
y_val_proba = final_model.predict_proba(X_val_log)[:, 1]

# Classification report
print("\nFinal Model Validation Classification Report:\n")
print(classification_report(y_val, y_val_pred, digits=4))

# ROC-AUC
roc_auc_val = roc_auc_score(y_val, y_val_proba)
print(f"Final Model Validation ROC-AUC Score: {roc_auc_val:.4f}")

# PR-AUC
pr_auc_val = average_precision_score(y_val, y_val_proba)
print(f"Final Model Validation PR-AUC Score: {pr_auc_val:.4f}")

# Confusion matrix
print("Final Model Validation Confusion Matrix:\n", confusion_matrix(y_val, y_val_pred))
# Out:
# Final Model Validation Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9975    0.7670    0.8672    106718
#            1     0.0476    0.8566    0.0902      1450
#
#     accuracy                         0.7682    108168
#    macro avg     0.5225    0.8118    0.4787    108168
# weighted avg     0.9847    0.7682    0.8568    108168
#
# Final Model Validation ROC-AUC Score: 0.8940
# Final Model Validation PR-AUC Score: 0.1828
# Final Model Validation Confusion Matrix:
#  [[81857 24861]
#  [  208  1242]]

# %%
# Evaluate on Test Set
y_test_pred = final_model.predict(X_test_log)
y_test_proba = final_model.predict_proba(X_test_log)[:, 1]
# Classification report
print("\nTest Classification Report:\n")
print(classification_report(y_test, y_test_pred, digits=4))
# ROC-AUC
roc_auc_test = roc_auc_score(y_test, y_test_proba)
print(f"Test ROC-AUC Score: {roc_auc_test:.4f}")
# PR-AUC
pr_auc_test = average_precision_score(y_test, y_test_proba)
print(f"Test PR-AUC Score: {pr_auc_test:.4f}")
# Confusion matrix
print("Test Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred))
# Out:
# Test Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9969    0.7937    0.8838     95415
#            1     0.0571    0.8347    0.1069      1428
#
#     accuracy                         0.7943     96843
#    macro avg     0.5270    0.8142    0.4953     96843
# weighted avg     0.9830    0.7943    0.8723     96843
#
# Test ROC-AUC Score: 0.8964
# Test PR-AUC Score: 0.2192
# Test Confusion Matrix:
#  [[75732 19683]
#  [  236  1192]]

# %% [markdown]
# # Use Non Log-Transformed Features

# %%
X_train_resampled_nolog = X_train_resampled.drop(columns=log_transformed_columns)
X_train_nolog = X_train.drop(columns=log_transformed_columns)
X_val_nolog = X_val.drop(columns=log_transformed_columns)
X_test_nolog = X_test.drop(columns=log_transformed_columns)

# %% [markdown]
# ## Use SMOTE resampled Training Data

# %% [markdown]
# ### Baseline

# %%
# Baseline XGBoost model
xgb_baseline = XGBClassifier(
    n_estimators=300,          # number of trees
    max_depth=6,               # tree depth
    learning_rate=0.2,         # step size shrinkage
    eval_metric='auc',     # evaluation metric
    random_state=42,
    n_jobs=-1                  # use all CPU cores
)

# Fit on training data
xgb_baseline.fit(X_train_resampled_nolog, y_train_resampled.values.ravel())
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.2, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=300,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %%
# Evaluate on Train Set
y_train_pred = xgb_baseline.predict(X_train_resampled_nolog)
y_train_proba = xgb_baseline.predict_proba(X_train_resampled_nolog)[:, 1]

# Classification report
print("Training Classification Report:\n")
print(classification_report(y_train_resampled, y_train_pred, digits=4))

# ROC-AUC
roc_auc_train = roc_auc_score(y_train_resampled, y_train_proba)
print(f"Training ROC-AUC Score: {roc_auc_train:.4f}")

# PR-AUC
pr_auc_train = average_precision_score(y_train_resampled, y_train_proba)
print(f"Training PR-AUC Score: {pr_auc_train:.4f}")

# Confusion matrix
print("Training Confusion Matrix:\n", confusion_matrix(y_train_resampled, y_train_pred))
# Out:
# Training Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9911    0.9995    0.9953    786838
#            1     0.9995    0.9911    0.9953    786838
#
#     accuracy                         0.9953   1573676
#    macro avg     0.9953    0.9953    0.9953   1573676
# weighted avg     0.9953    0.9953    0.9953   1573676
#
# Training ROC-AUC Score: 0.9996
# Training PR-AUC Score: 0.9996
# Training Confusion Matrix:
#  [[786467    371]
#  [  7040 779798]]

# %%
# Evaluate on validation Set
y_val_pred = xgb_baseline.predict(X_val_nolog)
y_val_proba = xgb_baseline.predict_proba(X_val_nolog)[:, 1]

# Classification report
print("\nValidation Classification Report:\n")
print(classification_report(y_val, y_val_pred, digits=4))
# ROC-AUC
roc_auc_val = roc_auc_score(y_val, y_val_proba)
print(f"Validation ROC-AUC Score: {roc_auc_val:.4f}")
# PR-AUC
pr_auc_val = average_precision_score(y_val, y_val_proba)
print(f"Validation PR-AUC Score: {pr_auc_val:.4f}")
# Confusion matrix
print("Validation Confusion Matrix:\n", confusion_matrix(y_val, y_val_pred))
# Out:
# Validation Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9876    0.9981    0.9928    106718
#            1     0.3500    0.0772    0.1266      1450
#
#     accuracy                         0.9857    108168
#    macro avg     0.6688    0.5376    0.5597    108168
# weighted avg     0.9790    0.9857    0.9812    108168
#
# Validation ROC-AUC Score: 0.8816
# Validation PR-AUC Score: 0.1482
# Validation Confusion Matrix:
#  [[106510    208]
#  [  1338    112]]

# %%
# Evaluate on Test Set
y_test_pred = xgb_baseline.predict(X_test_nolog)
y_test_proba = xgb_baseline.predict_proba(X_test_nolog)[:, 1]
# Classification report
print("\nTest Classification Report:\n")
print(classification_report(y_test, y_test_pred, digits=4))
# ROC-AUC
roc_auc_test = roc_auc_score(y_test, y_test_proba)
print(f"Test ROC-AUC Score: {roc_auc_test:.4f}")
# PR-AUC
pr_auc_test = average_precision_score(y_test, y_test_proba)
print(f"Test PR-AUC Score: {pr_auc_test:.4f}")
# Confusion matrix
print("Test Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred))
# Out:
# Test Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9862    0.9985    0.9923     95415
#            1     0.3966    0.0658    0.1129      1428
#
#     accuracy                         0.9847     96843
#    macro avg     0.6914    0.5322    0.5526     96843
# weighted avg     0.9775    0.9847    0.9793     96843
#
# Test ROC-AUC Score: 0.8722
# Test PR-AUC Score: 0.1695
# Test Confusion Matrix:
#  [[95272   143]
#  [ 1334    94]]

# %% [markdown]
# ### Hyperparameter Tuning

# %%
# Define objective function for Optuna
def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 200, 800),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 0.5),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "eval_metric": "auc",
        "random_state": 42,
        "n_jobs": -1
    }

    model = XGBClassifier(**params)

    model.fit(
        X_train_resampled_nolog, 
        y_train_resampled.values.ravel(),
        eval_set=[(X_val_nolog, y_val)],
        verbose=False
    )

    # Predict on validation
    preds = model.predict_proba(X_val_nolog)[:, 1]
    auc = roc_auc_score(y_val, preds)

    return auc

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)
print("Best params:", study.best_params)
print("Best AUC:", study.best_value)
# Out:
# [I 2025-11-08 20:56:07,442] A new study created in memory with name: no-name-2ec885e4-33f7-44a1-b40c-0cc5dcd55b24
# [I 2025-11-08 20:56:28,403] Trial 0 finished with value: 0.8605027914367933 and parameters: {'n_estimators': 674, 'max_depth': 4, 'learning_rate': 0.012079130208694536, 'subsample': 0.8073276520814414, 'colsample_bytree': 0.8751714909346767, 'gamma': 0.16480461846310113, 'min_child_weight': 10}. Best is trial 0 with value: 0.8605027914367933.
# [I 2025-11-08 20:56:40,083] Trial 1 finished with value: 0.883032533050366 and parameters: {'n_estimators': 370, 'max_depth': 5, 'learning_rate': 0.20603762130318634, 'subsample': 0.9495619494330149, 'colsample_bytree': 0.7000139941348612, 'gamma': 0.4899668403238577, 'min_child_weight': 1}. Best is trial 1 with value: 0.883032533050366.
# [I 2025-11-08 20:56:49,090] Trial 2 finished with value: 0.8794333115119384 and parameters: {'n_estimators': 241, 'max_depth': 6, 'learning_rate': 0.22031616355723949, 'subsample': 0.9043905897428742, 'colsample_bytree': 0.8477828372771705, 'gamma': 0.3379639213288391, 'min_child_weight': 2}. Best is trial 1 with value: 0.883032533050366.
# [I 2025-11-08 20:57:09,702] Trial 3 finished with value: 0.8585863775041019 and parameters: {'n_estimators': 426, 'max_depth': 10, 'learning_rate': 0.21491019694696364, 'subsample': 0.7323598559159678, 'colsample_bytree': 0.6330795067850556, 'gamma': 0.1476198969673091, 'min_child_weight': 5}. Best is trial 1 with value: 0.883032533050366.
# [I 2025-11-08 20:57:29,118] Trial 4 finished with value: 0.8805408873272842 and parameters: {'n_estimators': 518, 'max_depth': 7, 'learning_rate': 0.1129245259102142, 'subsample': 0.9509183421430604, 'colsample_bytree': 0.848402804563364, 'gamma': 0.04073857870492603, 'min_child_weight': 3}. Best is trial 1 with value: 0.883032533050366.
# [I 2025-11-08 20:57:38,856] Trial 5 finished with value: 0.8859877724793218 and parameters: {'n_estimators': 276, 'max_depth': 5, 'learning_rate': 0.13754290294708893, 'subsample': 0.9534255838718881, 'colsample_bytree': 0.6299575411653504, 'gamma': 0.010749182087088915, 'min_child_weight': 10}. Best is trial 5 with value: 0.8859877724793218.
# [I 2025-11-08 20:58:05,882] Trial 6 finished with value: 0.8813483715703198 and parameters: {'n_estimators': 559, 'max_depth': 10, 'learning_rate': 0.04988712405949559, 'subsample': 0.770701957205088, 'colsample_bytree': 0.8874588140134652, 'gamma': 0.4834766956454669, 'min_child_weight': 3}. Best is trial 5 with value: 0.8859877724793218.
# [I 2025-11-08 20:58:17,104] Trial 7 finished with value: 0.8570847014787926 and parameters: {'n_estimators': 264, 'max_depth': 10, 'learning_rate': 0.25224115071971037, 'subsample': 0.9727031045547141, 'colsample_bytree': 0.9194672762243187, 'gamma': 0.4705099448126907, 'min_child_weight': 3}. Best is trial 5 with value: 0.8859877724793218.
# [I 2025-11-08 20:58:33,267] Trial 8 finished with value: 0.878157664641133 and parameters: {'n_estimators': 553, 'max_depth': 4, 'learning_rate': 0.2500852969383343, 'subsample': 0.6866396189600439, 'colsample_bytree': 0.9239508526739615, 'gamma': 0.4460046385936115, 'min_child_weight': 7}. Best is trial 5 with value: 0.8859877724793218.
# [I 2025-11-08 20:58:57,812] Trial 9 finished with value: 0.8677290293270501 and parameters: {'n_estimators': 737, 'max_depth': 6, 'learning_rate': 0.21101603814727982, 'subsample': 0.9078363177947807, 'colsample_bytree': 0.6326285445543942, 'gamma': 0.3793727858375574, 'min_child_weight': 8}. Best is trial 5 with value: 0.8859877724793218.
# [I 2025-11-08 20:59:06,424] Trial 10 finished with value: 0.8847553138758868 and parameters: {'n_estimators': 200, 'max_depth': 8, 'learning_rate': 0.1306860001726776, 'subsample': 0.8377926814416857, 'colsample_bytree': 0.7536942788944332, 'gamma': 0.023546029296899706, 'min_child_weight': 10}. Best is trial 5 with value: 0.8859877724793218.
# [I 2025-11-08 20:59:15,720] Trial 11 finished with value: 0.8851819652309567 and parameters: {'n_estimators': 212, 'max_depth': 8, 'learning_rate': 0.13028571444313525, 'subsample': 0.8290646024431222, 'colsample_bytree': 0.7466918192584142, 'gamma': 0.00738769075986144, 'min_child_weight': 10}. Best is trial 5 with value: 0.8859877724793218.
# [I 2025-11-08 20:59:29,606] Trial 12 finished with value: 0.8853580076657074 and parameters: {'n_estimators': 338, 'max_depth': 8, 'learning_rate': 0.09031583764679008, 'subsample': 0.8570245608812038, 'colsample_bytree': 0.9990149187517209, 'gamma': 0.11668879151497033, 'min_child_weight': 8}. Best is trial 5 with value: 0.8859877724793218.
# [I 2025-11-08 20:59:39,365] Trial 13 finished with value: 0.8680787812675494 and parameters: {'n_estimators': 357, 'max_depth': 3, 'learning_rate': 0.06072937129258976, 'subsample': 0.8729239776460187, 'colsample_bytree': 0.9874322442738592, 'gamma': 0.12254150857607239, 'min_child_weight': 8}. Best is trial 5 with value: 0.8859877724793218.
# [I 2025-11-08 20:59:53,008] Trial 14 finished with value: 0.88488860102455 and parameters: {'n_estimators': 313, 'max_depth': 8, 'learning_rate': 0.08698779835750854, 'subsample': 0.6462620549253407, 'colsample_bytree': 0.9892107652191745, 'gamma': 0.23061076480376486, 'min_child_weight': 8}. Best is trial 5 with value: 0.8859877724793218.
# [I 2025-11-08 21:00:10,229] Trial 15 finished with value: 0.8769847506577114 and parameters: {'n_estimators': 454, 'max_depth': 7, 'learning_rate': 0.1688138808523416, 'subsample': 0.9995168109246175, 'colsample_bytree': 0.6006571997152743, 'gamma': 0.08551701725344787, 'min_child_weight': 6}. Best is trial 5 with value: 0.8859877724793218.
# [I 2025-11-08 21:00:20,177] Trial 16 finished with value: 0.8865146686950007 and parameters: {'n_estimators': 291, 'max_depth': 5, 'learning_rate': 0.16168858602182856, 'subsample': 0.8805190653415822, 'colsample_bytree': 0.7857519117627186, 'gamma': 0.20470756987079064, 'min_child_weight': 9}. Best is trial 16 with value: 0.8865146686950007.
# [I 2025-11-08 21:00:30,339] Trial 17 finished with value: 0.8859386646469489 and parameters: {'n_estimators': 298, 'max_depth': 5, 'learning_rate': 0.16319777520427553, 'subsample': 0.904401532426477, 'colsample_bytree': 0.7011622132472847, 'gamma': 0.22793968416945867, 'min_child_weight': 9}. Best is trial 16 with value: 0.8865146686950007.
# [I 2025-11-08 21:00:42,317] Trial 18 finished with value: 0.8862412894828846 and parameters: {'n_estimators': 420, 'max_depth': 3, 'learning_rate': 0.18632918022777817, 'subsample': 0.6006616550344885, 'colsample_bytree': 0.7901025719645024, 'gamma': 0.2816355698052032, 'min_child_weight': 5}. Best is trial 16 with value: 0.8865146686950007.
# [I 2025-11-08 21:00:53,708] Trial 19 finished with value: 0.8852483890834433 and parameters: {'n_estimators': 412, 'max_depth': 3, 'learning_rate': 0.2934670825580855, 'subsample': 0.7568452331545272, 'colsample_bytree': 0.8040399022354767, 'gamma': 0.2960675600414505, 'min_child_weight': 6}. Best is trial 16 with value: 0.8865146686950007.
# [I 2025-11-08 21:01:12,429] Trial 20 finished with value: 0.8843558143247011 and parameters: {'n_estimators': 630, 'max_depth': 4, 'learning_rate': 0.18042055653625372, 'subsample': 0.619327740360683, 'colsample_bytree': 0.7916510943854648, 'gamma': 0.1971825615080603, 'min_child_weight': 5}. Best is trial 16 with value: 0.8865146686950007.
# [I 2025-11-08 21:01:22,393] Trial 21 finished with value: 0.8870539404204829 and parameters: {'n_estimators': 291, 'max_depth': 5, 'learning_rate': 0.13999052056480446, 'subsample': 0.6939270950632078, 'colsample_bytree': 0.7129707130685865, 'gamma': 0.2621327086524987, 'min_child_weight': 4}. Best is trial 21 with value: 0.8870539404204829.
# [I 2025-11-08 21:01:33,497] Trial 22 finished with value: 0.8842467062726065 and parameters: {'n_estimators': 403, 'max_depth': 3, 'learning_rate': 0.1791005296415385, 'subsample': 0.6006221459596829, 'colsample_bytree': 0.7047153647363789, 'gamma': 0.2804950570373301, 'min_child_weight': 4}. Best is trial 21 with value: 0.8870539404204829.
# [I 2025-11-08 21:01:47,315] Trial 23 finished with value: 0.8867121598592745 and parameters: {'n_estimators': 472, 'max_depth': 4, 'learning_rate': 0.14521411380154414, 'subsample': 0.6883730487072024, 'colsample_bytree': 0.7669683019550253, 'gamma': 0.3451868438843341, 'min_child_weight': 4}. Best is trial 21 with value: 0.8870539404204829.
# [I 2025-11-08 21:02:11,042] Trial 24 finished with value: 0.8825033588361462 and parameters: {'n_estimators': 776, 'max_depth': 5, 'learning_rate': 0.14927688296864983, 'subsample': 0.6959637176327721, 'colsample_bytree': 0.7485687666142302, 'gamma': 0.38353779342165767, 'min_child_weight': 4}. Best is trial 21 with value: 0.8870539404204829.
# [I 2025-11-08 21:02:25,862] Trial 25 finished with value: 0.886487946641196 and parameters: {'n_estimators': 482, 'max_depth': 4, 'learning_rate': 0.10500824832096387, 'subsample': 0.6884137964072192, 'colsample_bytree': 0.673779387870821, 'gamma': 0.3318332958702852, 'min_child_weight': 4}. Best is trial 21 with value: 0.8870539404204829.
# [I 2025-11-08 21:02:47,387] Trial 26 finished with value: 0.8826122116231563 and parameters: {'n_estimators': 624, 'max_depth': 6, 'learning_rate': 0.1134509445042127, 'subsample': 0.7235453525041592, 'colsample_bytree': 0.7751662313085004, 'gamma': 0.3934737907492771, 'min_child_weight': 2}. Best is trial 21 with value: 0.8870539404204829.
# [I 2025-11-08 21:02:58,521] Trial 27 finished with value: 0.886385556261394 and parameters: {'n_estimators': 338, 'max_depth': 5, 'learning_rate': 0.1563501639322737, 'subsample': 0.6584659570266729, 'colsample_bytree': 0.826968113883295, 'gamma': 0.25111127286348583, 'min_child_weight': 7}. Best is trial 21 with value: 0.8870539404204829.
# [I 2025-11-08 21:03:06,287] Trial 28 finished with value: 0.870337434592361 and parameters: {'n_estimators': 240, 'max_depth': 4, 'learning_rate': 0.06495560865093221, 'subsample': 0.7821136278167112, 'colsample_bytree': 0.7273582411563532, 'gamma': 0.19871242069695144, 'min_child_weight': 6}. Best is trial 21 with value: 0.8870539404204829.
# [I 2025-11-08 21:03:25,140] Trial 29 finished with value: 0.8680476906264722 and parameters: {'n_estimators': 506, 'max_depth': 6, 'learning_rate': 0.015705215139871248, 'subsample': 0.7350650975123929, 'colsample_bytree': 0.6674271997589226, 'gamma': 0.3295171968785079, 'min_child_weight': 4}. Best is trial 21 with value: 0.8870539404204829.
# [I 2025-11-08 21:03:36,406] Trial 30 finished with value: 0.8853503852564057 and parameters: {'n_estimators': 370, 'max_depth': 4, 'learning_rate': 0.240426177004259, 'subsample': 0.7989506109197522, 'colsample_bytree': 0.8157148525839767, 'gamma': 0.18300007929202927, 'min_child_weight': 2}. Best is trial 21 with value: 0.8870539404204829.
# [I 2025-11-08 21:03:50,644] Trial 31 finished with value: 0.8850652541567818 and parameters: {'n_estimators': 460, 'max_depth': 4, 'learning_rate': 0.10322246355049655, 'subsample': 0.6886467900703518, 'colsample_bytree': 0.6767355524878452, 'gamma': 0.32372711055864467, 'min_child_weight': 4}. Best is trial 21 with value: 0.8870539404204829.
# [I 2025-11-08 21:04:06,341] Trial 32 finished with value: 0.8851178936946938 and parameters: {'n_estimators': 469, 'max_depth': 5, 'learning_rate': 0.13946834272853356, 'subsample': 0.6615810068485228, 'colsample_bytree': 0.668748541373228, 'gamma': 0.4176054741463048, 'min_child_weight': 3}. Best is trial 21 with value: 0.8870539404204829.
# [I 2025-11-08 21:04:22,758] Trial 33 finished with value: 0.8882226409144047 and parameters: {'n_estimators': 562, 'max_depth': 4, 'learning_rate': 0.12064659132576223, 'subsample': 0.7042013150314061, 'colsample_bytree': 0.7335929096705829, 'gamma': 0.3548085866538887, 'min_child_weight': 1}. Best is trial 33 with value: 0.8882226409144047.
# [I 2025-11-08 21:04:42,306] Trial 34 finished with value: 0.8755569205595669 and parameters: {'n_estimators': 606, 'max_depth': 5, 'learning_rate': 0.20149761765921528, 'subsample': 0.716188382944169, 'colsample_bytree': 0.7722365175846367, 'gamma': 0.3548522487571795, 'min_child_weight': 1}. Best is trial 33 with value: 0.8882226409144047.
# [I 2025-11-08 21:05:06,268] Trial 35 finished with value: 0.8803246842629397 and parameters: {'n_estimators': 682, 'max_depth': 6, 'learning_rate': 0.12210094205436728, 'subsample': 0.7489643339708412, 'colsample_bytree': 0.7275596398148515, 'gamma': 0.2583419606600954, 'min_child_weight': 1}. Best is trial 33 with value: 0.8882226409144047.
# [I 2025-11-08 21:05:21,756] Trial 36 finished with value: 0.8859177167539847 and parameters: {'n_estimators': 551, 'max_depth': 3, 'learning_rate': 0.14953424972863855, 'subsample': 0.6433169367432047, 'colsample_bytree': 0.7237160205916778, 'gamma': 0.3088580476506376, 'min_child_weight': 2}. Best is trial 33 with value: 0.8882226409144047.
# [I 2025-11-08 21:05:39,450] Trial 37 finished with value: 0.888710814386094 and parameters: {'n_estimators': 588, 'max_depth': 4, 'learning_rate': 0.09741085019817369, 'subsample': 0.8059981604698717, 'colsample_bytree': 0.8445755391448475, 'gamma': 0.36770144098801916, 'min_child_weight': 5}. Best is trial 37 with value: 0.888710814386094.
# [I 2025-11-08 21:05:59,822] Trial 38 finished with value: 0.8892288700287124 and parameters: {'n_estimators': 679, 'max_depth': 4, 'learning_rate': 0.0832359466619082, 'subsample': 0.8083814366120015, 'colsample_bytree': 0.8543155922196343, 'gamma': 0.3643531689328112, 'min_child_weight': 5}. Best is trial 38 with value: 0.8892288700287124.
# [I 2025-11-08 21:06:19,881] Trial 39 finished with value: 0.8736488366697663 and parameters: {'n_estimators': 681, 'max_depth': 4, 'learning_rate': 0.030189810987527863, 'subsample': 0.8088712992820477, 'colsample_bytree': 0.8691637491964497, 'gamma': 0.44781125571476094, 'min_child_weight': 5}. Best is trial 38 with value: 0.8892288700287124.
# [I 2025-11-08 21:06:36,285] Trial 40 finished with value: 0.8796997791795457 and parameters: {'n_estimators': 594, 'max_depth': 3, 'learning_rate': 0.08231415177487711, 'subsample': 0.789330221146474, 'colsample_bytree': 0.8464582183766703, 'gamma': 0.42026548970657246, 'min_child_weight': 7}. Best is trial 38 with value: 0.8892288700287124.
# [I 2025-11-08 21:06:55,767] Trial 41 finished with value: 0.8863906938751244 and parameters: {'n_estimators': 645, 'max_depth': 4, 'learning_rate': 0.07116374325994604, 'subsample': 0.8197021930950176, 'colsample_bytree': 0.9002117152264583, 'gamma': 0.36097002388073146, 'min_child_weight': 5}. Best is trial 38 with value: 0.8892288700287124.
# [I 2025-11-08 21:07:16,059] Trial 42 finished with value: 0.8892431131741986 and parameters: {'n_estimators': 716, 'max_depth': 4, 'learning_rate': 0.0975392923598307, 'subsample': 0.7664092681247394, 'colsample_bytree': 0.8346491192678072, 'gamma': 0.3549539964042876, 'min_child_weight': 6}. Best is trial 42 with value: 0.8892431131741986.
# [I 2025-11-08 21:07:38,722] Trial 43 finished with value: 0.8851258456867632 and parameters: {'n_estimators': 729, 'max_depth': 5, 'learning_rate': 0.042053689115851486, 'subsample': 0.7725587225690866, 'colsample_bytree': 0.8604909511885577, 'gamma': 0.4237643178263432, 'min_child_weight': 6}. Best is trial 42 with value: 0.8892431131741986.
# [I 2025-11-08 21:07:59,748] Trial 44 finished with value: 0.8895065144295858 and parameters: {'n_estimators': 712, 'max_depth': 4, 'learning_rate': 0.09986848975318872, 'subsample': 0.7597662645423839, 'colsample_bytree': 0.836636691377709, 'gamma': 0.3685431876571106, 'min_child_weight': 7}. Best is trial 44 with value: 0.8895065144295858.
# [I 2025-11-08 21:08:19,371] Trial 45 finished with value: 0.8862417903194433 and parameters: {'n_estimators': 724, 'max_depth': 3, 'learning_rate': 0.10045027450987185, 'subsample': 0.755591583406903, 'colsample_bytree': 0.8351111061494525, 'gamma': 0.376018719991891, 'min_child_weight': 7}. Best is trial 44 with value: 0.8895065144295858.
# [I 2025-11-08 21:08:41,493] Trial 46 finished with value: 0.8882068629472066 and parameters: {'n_estimators': 794, 'max_depth': 4, 'learning_rate': 0.07859358306305414, 'subsample': 0.8446844978314837, 'colsample_bytree': 0.8932982008159869, 'gamma': 0.40054332747332483, 'min_child_weight': 7}. Best is trial 44 with value: 0.8895065144295858.
# [I 2025-11-08 21:09:12,279] Trial 47 finished with value: 0.8653637818265477 and parameters: {'n_estimators': 705, 'max_depth': 9, 'learning_rate': 0.11834746866035072, 'subsample': 0.8087547401156128, 'colsample_bytree': 0.9139683405257716, 'gamma': 0.4964095064774695, 'min_child_weight': 6}. Best is trial 44 with value: 0.8895065144295858.
# [I 2025-11-08 21:09:41,330] Trial 48 finished with value: 0.88746619030109 and parameters: {'n_estimators': 756, 'max_depth': 7, 'learning_rate': 0.05439579711578038, 'subsample': 0.7127580453701843, 'colsample_bytree': 0.9345061327301165, 'gamma': 0.45172860476422927, 'min_child_weight': 3}. Best is trial 44 with value: 0.8895065144295858.
# [I 2025-11-08 21:09:59,554] Trial 49 finished with value: 0.8828675510255517 and parameters: {'n_estimators': 656, 'max_depth': 3, 'learning_rate': 0.08817440622160534, 'subsample': 0.7455514364939989, 'colsample_bytree': 0.8114446234990134, 'gamma': 0.35370800865593194, 'min_child_weight': 9}. Best is trial 44 with value: 0.8895065144295858.
# Best params: {'n_estimators': 712, 'max_depth': 4, 'learning_rate': 0.09986848975318872, 'subsample': 0.7597662645423839, 'colsample_bytree': 0.836636691377709, 'gamma': 0.3685431876571106, 'min_child_weight': 7}
# Best AUC: 0.8895065144295858

# %%
# Extract best parameters
best_params = study.best_params  # from Optuna study

# Train best model on training set
final_model = XGBClassifier(**best_params)
final_model.fit(X_train_resampled_nolog, y_train_resampled.values.ravel())
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.836636691377709, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, feature_weights=None,
#               gamma=0.3685431876571106, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.09986848975318872,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=7, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=712, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
# Evaluate on Train Set
y_train_pred = final_model.predict(X_train_resampled_nolog)
y_train_proba = final_model.predict_proba(X_train_resampled_nolog)[:, 1]

# Classification report
print("Final Model Training Classification Report:\n")
print(classification_report(y_train_resampled, y_train_pred, digits=4))
# ROC-AUC
roc_auc_train = roc_auc_score(y_train_resampled, y_train_proba)
print(f"Final Model Training ROC-AUC Score: {roc_auc_train:.4f}")
# PR-AUC
pr_auc_train = average_precision_score(y_train_resampled, y_train_proba)
print(f"Final Model Training PR-AUC Score: {pr_auc_train:.4f}")
# Confusion matrix
print("Final Model Training Confusion Matrix:\n", confusion_matrix(y_train_resampled, y_train_pred))
# Out:
# Final Model Training Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9899    0.9990    0.9944    786838
#            1     0.9990    0.9898    0.9944    786838
#
#     accuracy                         0.9944   1573676
#    macro avg     0.9944    0.9944    0.9944   1573676
# weighted avg     0.9944    0.9944    0.9944   1573676
#
# Final Model Training ROC-AUC Score: 0.9991
# Final Model Training PR-AUC Score: 0.9993
# Final Model Training Confusion Matrix:
#  [[786052    786]
#  [  8056 778782]]

# %%
# Evaluate on Validation Set
y_val_pred = final_model.predict(X_val_nolog)
y_val_proba = final_model.predict_proba(X_val_nolog)[:, 1]
# Classification report
print("\nFinal Model Validation Classification Report:\n")
print(classification_report(y_val, y_val_pred, digits=4))
# ROC-AUC
roc_auc_val = roc_auc_score(y_val, y_val_proba)
print(f"Final Model Validation ROC-AUC Score: {roc_auc_val:.4f}")
# PR-AUC
pr_auc_val = average_precision_score(y_val, y_val_proba)
print(f"Final Model Validation PR-AUC Score: {pr_auc_val:.4f}")
# Confusion matrix
print("Final Model Validation Confusion Matrix:\n", confusion_matrix(y_val, y_val_pred))
# Out:
# Final Model Validation Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9877    0.9979    0.9928    106718
#            1     0.3671    0.0876    0.1414      1450
#
#     accuracy                         0.9857    108168
#    macro avg     0.6774    0.5428    0.5671    108168
# weighted avg     0.9794    0.9857    0.9814    108168
#
# Final Model Validation ROC-AUC Score: 0.8894
# Final Model Validation PR-AUC Score: 0.1623
# Final Model Validation Confusion Matrix:
#  [[106499    219]
#  [  1323    127]]

# %%
# Evaluate on Test Set
y_test_pred = final_model.predict(X_test_nolog)
y_test_proba = final_model.predict_proba(X_test_nolog)[:, 1]
# Classification report
print("\nTest Classification Report:\n")
print(classification_report(y_test, y_test_pred, digits=4))
# ROC-AUC
roc_auc_test = roc_auc_score(y_test, y_test_proba)
print(f"Test ROC-AUC Score: {roc_auc_test:.4f}")
# PR-AUC
pr_auc_test = average_precision_score(y_test, y_test_proba)
print(f"Test PR-AUC Score: {pr_auc_test:.4f}")
# Confusion matrix
print("Test Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred))
# Out:
# Test Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9863    0.9986    0.9924     95415
#            1     0.4380    0.0742    0.1269      1428
#
#     accuracy                         0.9849     96843
#    macro avg     0.7122    0.5364    0.5597     96843
# weighted avg     0.9782    0.9849    0.9796     96843
#
# Test ROC-AUC Score: 0.8842
# Test PR-AUC Score: 0.1900
# Test Confusion Matrix:
#  [[95279   136]
#  [ 1322   106]]

# %% [markdown]
# ## Use original train with class weighting

# %% [markdown]
# ### Baseline

# %%
# Extract 1D labels
y = y_train['fraud_bool'].values

# Compute class weight correctly
pos = (y == 1).sum()
neg = (y == 0).sum()
scale = neg / pos

# Baseline XGBoost model
xgb_baseline = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.2,
    eval_metric='auc',
    random_state=42,
    scale_pos_weight=scale,   # float, not Series
    n_jobs=-1
)

# Fit
xgb_baseline.fit(X_train_nolog, y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.2, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=300,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %%
# Evaluate on Validation Set
y_val_pred = xgb_baseline.predict(X_val_nolog)
y_val_proba = xgb_baseline.predict_proba(X_val_nolog)[:, 1]  

# Classification report
print("\nValidation Classification Report:\n")
print(classification_report(y_val, y_val_pred, digits=4))

# ROC-AUC
roc_auc_val = roc_auc_score(y_val, y_val_proba)
print(f"Validation ROC-AUC Score: {roc_auc_val:.4f}")

# PR-AUC
pr_auc_val = average_precision_score(y_val, y_val_proba)
print(f"Validation PR-AUC Score: {pr_auc_val:.4f}")

# Confusion matrix
print("Validation Confusion Matrix:\n", confusion_matrix(y_val, y_val_pred))
# Out:
# Validation Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9941    0.9053    0.9476    106718
#            1     0.0794    0.6014    0.1403      1450
#
#     accuracy                         0.9012    108168
#    macro avg     0.5367    0.7533    0.5439    108168
# weighted avg     0.9818    0.9012    0.9368    108168
#
# Validation ROC-AUC Score: 0.8661
# Validation PR-AUC Score: 0.1438
# Validation Confusion Matrix:
#  [[96608 10110]
#  [  578   872]]

# %%
# Evaluate on Test Set
y_test_pred = xgb_baseline.predict(X_test_nolog)
y_test_proba = xgb_baseline.predict_proba(X_test_nolog)[:, 1]
# Classification report
print("\nTest Classification Report:\n")
print(classification_report(y_test, y_test_pred, digits=4))
# ROC-AUC
roc_auc_test = roc_auc_score(y_test, y_test_proba)
print(f"Test ROC-AUC Score: {roc_auc_test:.4f}")
# PR-AUC
pr_auc_test = average_precision_score(y_test, y_test_proba)
print(f"Test PR-AUC Score: {pr_auc_test:.4f}")
# Confusion matrix
print("Test Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred))
# Out:
# Test Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9911    0.9518    0.9711     95415
#            1     0.1175    0.4286    0.1844      1428
#
#     accuracy                         0.9441     96843
#    macro avg     0.5543    0.6902    0.5777     96843
# weighted avg     0.9782    0.9441    0.9595     96843
#
# Test ROC-AUC Score: 0.8454
# Test PR-AUC Score: 0.1350
# Test Confusion Matrix:
#  [[90818  4597]
#  [  816   612]]

# %% [markdown]
# ### Hyperparameter Tuning

# %%
import optuna
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score

def objective(trial):

    # Suggest hyperparameters
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 200, 800),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 5),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 20),
        
        # Tune scale_pos_weight around the base imbalance ratio
        "scale_pos_weight": trial.suggest_float(
            "scale_pos_weight", 
            scale * 0.5, 
            scale * 2.0
        ),

        "early_stopping_rounds": 50,
        "eval_metric": "auc",
        "random_state": 42,
        "n_jobs": -1,
    }

    model = XGBClassifier(**params)

    model.fit(
        X_train_nolog, 
        y,
        eval_set=[(X_val_nolog, y_val)],
        verbose=False
    )

    # Predict on validation
    preds = model.predict_proba(X_val_nolog)[:, 1]
    auc = roc_auc_score(y_val, preds)

    return auc

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)
print("Best params:", study.best_params)
# Out:
# [I 2025-11-10 14:54:52,782] A new study created in memory with name: no-name-c178e9ae-18b2-4239-b752-7867f4beb353
# [I 2025-11-10 14:55:02,774] Trial 0 finished with value: 0.8919360176449568 and parameters: {'n_estimators': 452, 'max_depth': 6, 'learning_rate': 0.0399941378145437, 'subsample': 0.8209946780281052, 'colsample_bytree': 0.6133022249718514, 'gamma': 1.4303431977334284, 'min_child_weight': 11, 'scale_pos_weight': 135.98354671415194}. Best is trial 0 with value: 0.8919360176449568.
# [I 2025-11-10 14:55:05,359] Trial 1 finished with value: 0.856017166738507 and parameters: {'n_estimators': 616, 'max_depth': 10, 'learning_rate': 0.255208994711477, 'subsample': 0.6633452047213713, 'colsample_bytree': 0.7091433134635231, 'gamma': 2.2628438331995566, 'min_child_weight': 11, 'scale_pos_weight': 167.26277126757253}. Best is trial 0 with value: 0.8919360176449568.
# [I 2025-11-10 14:55:09,433] Trial 2 finished with value: 0.8926208098559465 and parameters: {'n_estimators': 313, 'max_depth': 4, 'learning_rate': 0.18018477163785504, 'subsample': 0.8350312740429704, 'colsample_bytree': 0.9473905581250592, 'gamma': 0.8862360788246881, 'min_child_weight': 8, 'scale_pos_weight': 113.1303247609906}. Best is trial 2 with value: 0.8926208098559465.
# [I 2025-11-10 14:55:22,347] Trial 3 finished with value: 0.8935223285862643 and parameters: {'n_estimators': 584, 'max_depth': 5, 'learning_rate': 0.029253114602891584, 'subsample': 0.9574196570260587, 'colsample_bytree': 0.672711232241522, 'gamma': 0.509714809363353, 'min_child_weight': 12, 'scale_pos_weight': 77.07202435163073}. Best is trial 3 with value: 0.8935223285862643.
# [I 2025-11-10 14:55:32,112] Trial 4 finished with value: 0.8943730398711137 and parameters: {'n_estimators': 578, 'max_depth': 3, 'learning_rate': 0.06745455131194068, 'subsample': 0.9015719741949735, 'colsample_bytree': 0.8772552328643967, 'gamma': 1.6960964713355424, 'min_child_weight': 16, 'scale_pos_weight': 171.57240790169746}. Best is trial 4 with value: 0.8943730398711137.
# [I 2025-11-10 14:55:35,570] Trial 5 finished with value: 0.8862353925363073 and parameters: {'n_estimators': 285, 'max_depth': 7, 'learning_rate': 0.12134292659189766, 'subsample': 0.8614935615055934, 'colsample_bytree': 0.6261342257978297, 'gamma': 0.05752845567339515, 'min_child_weight': 19, 'scale_pos_weight': 87.67659535165826}. Best is trial 4 with value: 0.8943730398711137.
# [I 2025-11-10 14:55:39,046] Trial 6 finished with value: 0.8925053977256203 and parameters: {'n_estimators': 340, 'max_depth': 3, 'learning_rate': 0.21250172751811397, 'subsample': 0.6551236682212696, 'colsample_bytree': 0.7341514830507861, 'gamma': 0.3034206063870143, 'min_child_weight': 3, 'scale_pos_weight': 173.27948962389178}. Best is trial 4 with value: 0.8943730398711137.
# [I 2025-11-10 14:55:46,089] Trial 7 finished with value: 0.8847885371113428 and parameters: {'n_estimators': 238, 'max_depth': 7, 'learning_rate': 0.016331347464975016, 'subsample': 0.9734116591413098, 'colsample_bytree': 0.8787183335980271, 'gamma': 1.535057696060202, 'min_child_weight': 1, 'scale_pos_weight': 69.02083878402048}. Best is trial 4 with value: 0.8943730398711137.
# [I 2025-11-10 14:55:48,387] Trial 8 finished with value: 0.8841751835808329 and parameters: {'n_estimators': 506, 'max_depth': 6, 'learning_rate': 0.2746148766844475, 'subsample': 0.728154919402135, 'colsample_bytree': 0.8730102104609506, 'gamma': 0.45682919657412335, 'min_child_weight': 9, 'scale_pos_weight': 159.30607908808474}. Best is trial 4 with value: 0.8943730398711137.
# [I 2025-11-10 14:55:50,876] Trial 9 finished with value: 0.8803435512607835 and parameters: {'n_estimators': 496, 'max_depth': 7, 'learning_rate': 0.22299379570712843, 'subsample': 0.8684337753948093, 'colsample_bytree': 0.6221188032735215, 'gamma': 1.8845996181341251, 'min_child_weight': 19, 'scale_pos_weight': 189.5050342031017}. Best is trial 4 with value: 0.8943730398711137.
# [I 2025-11-10 14:55:54,760] Trial 10 finished with value: 0.8767508179791924 and parameters: {'n_estimators': 769, 'max_depth': 9, 'learning_rate': 0.08206850947908534, 'subsample': 0.9146951703805739, 'colsample_bytree': 0.9936607278848475, 'gamma': 3.5436079185969187, 'min_child_weight': 16, 'scale_pos_weight': 132.77942680644728}. Best is trial 4 with value: 0.8943730398711137.
# [I 2025-11-10 14:56:07,621] Trial 11 finished with value: 0.8945187509976342 and parameters: {'n_estimators': 650, 'max_depth': 4, 'learning_rate': 0.032442710290995165, 'subsample': 0.977399972130174, 'colsample_bytree': 0.7794216050565447, 'gamma': 3.4929371067476214, 'min_child_weight': 14, 'scale_pos_weight': 51.4537683033153}. Best is trial 11 with value: 0.8945187509976342.
# [I 2025-11-10 14:56:17,278] Trial 12 finished with value: 0.8950586948134659 and parameters: {'n_estimators': 740, 'max_depth': 3, 'learning_rate': 0.06539984612374716, 'subsample': 0.9913793376192805, 'colsample_bytree': 0.8077515150048845, 'gamma': 3.1974797278619365, 'min_child_weight': 15, 'scale_pos_weight': 50.59895682011484}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:56:32,607] Trial 13 finished with value: 0.8941422123792581 and parameters: {'n_estimators': 782, 'max_depth': 4, 'learning_rate': 0.022896487488097743, 'subsample': 0.9864411199889489, 'colsample_bytree': 0.7802241179486077, 'gamma': 3.541120399968115, 'min_child_weight': 15, 'scale_pos_weight': 48.28095185049677}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:56:46,677] Trial 14 finished with value: 0.8882179912124186 and parameters: {'n_estimators': 692, 'max_depth': 4, 'learning_rate': 0.010091237668062338, 'subsample': 0.7521522769987561, 'colsample_bytree': 0.8093967758047387, 'gamma': 4.893509178549489, 'min_child_weight': 14, 'scale_pos_weight': 48.898052755793074}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:56:58,949] Trial 15 finished with value: 0.894241054897503 and parameters: {'n_estimators': 681, 'max_depth': 3, 'learning_rate': 0.046200969023217894, 'subsample': 0.9289937831198987, 'colsample_bytree': 0.8030552031899507, 'gamma': 3.1522024462421627, 'min_child_weight': 7, 'scale_pos_weight': 98.99794062952785}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:57:03,812] Trial 16 finished with value: 0.8932494954475573 and parameters: {'n_estimators': 706, 'max_depth': 5, 'learning_rate': 0.09265818447571847, 'subsample': 0.993779908592917, 'colsample_bytree': 0.7573059367338097, 'gamma': 4.652115451875873, 'min_child_weight': 20, 'scale_pos_weight': 65.1192713682931}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:57:14,865] Trial 17 finished with value: 0.8938558340350431 and parameters: {'n_estimators': 629, 'max_depth': 5, 'learning_rate': 0.03270495155905561, 'subsample': 0.6015341492358319, 'colsample_bytree': 0.8351665920321903, 'gamma': 4.2097267574140655, 'min_child_weight': 13, 'scale_pos_weight': 108.15197823663772}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:57:20,797] Trial 18 finished with value: 0.8857149716526509 and parameters: {'n_estimators': 796, 'max_depth': 8, 'learning_rate': 0.05561600002764506, 'subsample': 0.7678216767249249, 'colsample_bytree': 0.68662310686103, 'gamma': 2.895561068309783, 'min_child_weight': 17, 'scale_pos_weight': 84.89666115019409}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:57:35,110] Trial 19 finished with value: 0.8928574179710498 and parameters: {'n_estimators': 722, 'max_depth': 4, 'learning_rate': 0.018012309473298332, 'subsample': 0.9503238664278462, 'colsample_bytree': 0.9173781246181203, 'gamma': 4.09698043234563, 'min_child_weight': 18, 'scale_pos_weight': 61.79473823690069}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:57:40,670] Trial 20 finished with value: 0.893904958023434 and parameters: {'n_estimators': 422, 'max_depth': 3, 'learning_rate': 0.12911554316748178, 'subsample': 0.8911908254603058, 'colsample_bytree': 0.7550543156024709, 'gamma': 2.6783418371266725, 'min_child_weight': 6, 'scale_pos_weight': 97.59454621794136}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:57:51,019] Trial 21 finished with value: 0.8939665900009758 and parameters: {'n_estimators': 569, 'max_depth': 3, 'learning_rate': 0.06519189020182559, 'subsample': 0.9229203643740957, 'colsample_bytree': 0.8506327642219045, 'gamma': 2.309943587411022, 'min_child_weight': 15, 'scale_pos_weight': 144.99941848249287}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:58:02,618] Trial 22 finished with value: 0.8937503384685774 and parameters: {'n_estimators': 645, 'max_depth': 3, 'learning_rate': 0.06424727945824733, 'subsample': 0.9993410985365146, 'colsample_bytree': 0.8950000165324303, 'gamma': 3.3523017950542857, 'min_child_weight': 13, 'scale_pos_weight': 188.92955835852527}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:58:13,666] Trial 23 finished with value: 0.8946177259952268 and parameters: {'n_estimators': 555, 'max_depth': 4, 'learning_rate': 0.041655313414066614, 'subsample': 0.8895361425349725, 'colsample_bytree': 0.8340734258917444, 'gamma': 3.8400522736699156, 'min_child_weight': 17, 'scale_pos_weight': 123.14784551996667}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:58:23,846] Trial 24 finished with value: 0.8927813392821945 and parameters: {'n_estimators': 523, 'max_depth': 5, 'learning_rate': 0.03482002827655662, 'subsample': 0.9366091958288261, 'colsample_bytree': 0.8273229585142594, 'gamma': 3.988600296851718, 'min_child_weight': 17, 'scale_pos_weight': 122.86974411136478}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:58:38,438] Trial 25 finished with value: 0.8947003834146197 and parameters: {'n_estimators': 732, 'max_depth': 4, 'learning_rate': 0.025040132052864247, 'subsample': 0.8735500723628462, 'colsample_bytree': 0.7778614202795588, 'gamma': 3.7481380436609113, 'min_child_weight': 14, 'scale_pos_weight': 57.95452861256091}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:58:51,375] Trial 26 finished with value: 0.8922144213786771 and parameters: {'n_estimators': 747, 'max_depth': 6, 'learning_rate': 0.02290567015722663, 'subsample': 0.7943862772390299, 'colsample_bytree': 0.7243174178703177, 'gamma': 4.394411975650632, 'min_child_weight': 17, 'scale_pos_weight': 77.66460343952693}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:58:59,537] Trial 27 finished with value: 0.8820786849776822 and parameters: {'n_estimators': 387, 'max_depth': 4, 'learning_rate': 0.01184913749293681, 'subsample': 0.8658452187785388, 'colsample_bytree': 0.7800343920156947, 'gamma': 3.7183741250561337, 'min_child_weight': 20, 'scale_pos_weight': 123.49624298453611}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:59:08,579] Trial 28 finished with value: 0.8923943509513632 and parameters: {'n_estimators': 747, 'max_depth': 5, 'learning_rate': 0.04545036242555833, 'subsample': 0.8322386846585919, 'colsample_bytree': 0.8501093452363059, 'gamma': 3.010377287291845, 'min_child_weight': 15, 'scale_pos_weight': 147.6643404312194}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:59:19,829] Trial 29 finished with value: 0.8921715853124994 and parameters: {'n_estimators': 469, 'max_depth': 6, 'learning_rate': 0.02453420908228383, 'subsample': 0.8161480644073065, 'colsample_bytree': 0.9292815402565877, 'gamma': 3.9128298959584162, 'min_child_weight': 11, 'scale_pos_weight': 62.096235327340835}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:59:30,388] Trial 30 finished with value: 0.8941778493238061 and parameters: {'n_estimators': 543, 'max_depth': 4, 'learning_rate': 0.04396050611584561, 'subsample': 0.874997375774837, 'colsample_bytree': 0.8114021824567514, 'gamma': 4.556289076219972, 'min_child_weight': 10, 'scale_pos_weight': 132.93984329784308}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:59:43,503] Trial 31 finished with value: 0.8915010653278281 and parameters: {'n_estimators': 658, 'max_depth': 4, 'learning_rate': 0.016286394693189002, 'subsample': 0.9652142405363383, 'colsample_bytree': 0.7826180986616538, 'gamma': 3.397001493254456, 'min_child_weight': 13, 'scale_pos_weight': 58.864616784789256}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 14:59:54,720] Trial 32 finished with value: 0.8934754535155819 and parameters: {'n_estimators': 612, 'max_depth': 3, 'learning_rate': 0.03410377116582789, 'subsample': 0.9454426079095931, 'colsample_bytree': 0.7535789334373132, 'gamma': 2.4690054745758276, 'min_child_weight': 14, 'scale_pos_weight': 54.65634875502058}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 15:00:09,088] Trial 33 finished with value: 0.8946311484149977 and parameters: {'n_estimators': 729, 'max_depth': 4, 'learning_rate': 0.02713824185109041, 'subsample': 0.8949330373250853, 'colsample_bytree': 0.8334117962028553, 'gamma': 2.83050923746161, 'min_child_weight': 12, 'scale_pos_weight': 69.1487822178335}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 15:00:25,057] Trial 34 finished with value: 0.8936934240482975 and parameters: {'n_estimators': 732, 'max_depth': 5, 'learning_rate': 0.018958108956456506, 'subsample': 0.8422415775965848, 'colsample_bytree': 0.8381668670413116, 'gamma': 2.8153359826957076, 'min_child_weight': 12, 'scale_pos_weight': 72.22893117005215}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 15:00:32,786] Trial 35 finished with value: 0.8767783930707485 and parameters: {'n_estimators': 681, 'max_depth': 10, 'learning_rate': 0.028354443914370003, 'subsample': 0.8935543883264289, 'colsample_bytree': 0.8607173256882005, 'gamma': 2.0372590603146823, 'min_child_weight': 12, 'scale_pos_weight': 106.29947154975622}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 15:00:44,189] Trial 36 finished with value: 0.8940124698609484 and parameters: {'n_estimators': 755, 'max_depth': 4, 'learning_rate': 0.05335642382125362, 'subsample': 0.7897094885443389, 'colsample_bytree': 0.6969588514338703, 'gamma': 3.204762164608283, 'min_child_weight': 9, 'scale_pos_weight': 84.65326025934215}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 15:00:55,489] Trial 37 finished with value: 0.8940959447748529 and parameters: {'n_estimators': 598, 'max_depth': 3, 'learning_rate': 0.038167222132400876, 'subsample': 0.8436487613615897, 'colsample_bytree': 0.6539072630012339, 'gamma': 3.7960851217271347, 'min_child_weight': 16, 'scale_pos_weight': 94.15610639440962}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 15:01:01,821] Trial 38 finished with value: 0.8933222750775328 and parameters: {'n_estimators': 713, 'max_depth': 5, 'learning_rate': 0.08377114021419348, 'subsample': 0.9066658923182941, 'colsample_bytree': 0.8995700272090112, 'gamma': 1.0402491133473566, 'min_child_weight': 18, 'scale_pos_weight': 75.16308903846746}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 15:01:16,793] Trial 39 finished with value: 0.8890986557546766 and parameters: {'n_estimators': 792, 'max_depth': 3, 'learning_rate': 0.01350865140035331, 'subsample': 0.7174596449820536, 'colsample_bytree': 0.965359304769803, 'gamma': 2.58913588475173, 'min_child_weight': 10, 'scale_pos_weight': 68.3524202833359}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 15:01:28,666] Trial 40 finished with value: 0.8920997071883295 and parameters: {'n_estimators': 557, 'max_depth': 6, 'learning_rate': 0.026665326830241625, 'subsample': 0.8146075360551015, 'colsample_bytree': 0.7286119571710874, 'gamma': 4.300249586131149, 'min_child_weight': 5, 'scale_pos_weight': 113.32258806411606}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 15:01:41,999] Trial 41 finished with value: 0.893469210830219 and parameters: {'n_estimators': 659, 'max_depth': 4, 'learning_rate': 0.021224495235860636, 'subsample': 0.9671801022668443, 'colsample_bytree': 0.7934837367006591, 'gamma': 3.597508728291477, 'min_child_weight': 14, 'scale_pos_weight': 52.42993352672289}. Best is trial 12 with value: 0.8950586948134659.
# [I 2025-11-10 15:01:55,656] Trial 42 finished with value: 0.8954940187190087 and parameters: {'n_estimators': 668, 'max_depth': 4, 'learning_rate': 0.041220581254456184, 'subsample': 0.8866972561799367, 'colsample_bytree': 0.8225361744537156, 'gamma': 2.977080553654553, 'min_child_weight': 11, 'scale_pos_weight': 56.656079473016156}. Best is trial 42 with value: 0.8954940187190087.
# [I 2025-11-10 15:02:04,521] Trial 43 finished with value: 0.8942002803392246 and parameters: {'n_estimators': 697, 'max_depth': 4, 'learning_rate': 0.056237388695065726, 'subsample': 0.8788400075525956, 'colsample_bytree': 0.8181856049671794, 'gamma': 3.0754133663839203, 'min_child_weight': 11, 'scale_pos_weight': 58.054266627975494}. Best is trial 42 with value: 0.8954940187190087.
# [I 2025-11-10 15:02:15,692] Trial 44 finished with value: 0.8931332884411445 and parameters: {'n_estimators': 767, 'max_depth': 5, 'learning_rate': 0.04159273838588432, 'subsample': 0.8549099367280587, 'colsample_bytree': 0.8672520930388493, 'gamma': 3.2449945384335113, 'min_child_weight': 9, 'scale_pos_weight': 79.53622585073738}. Best is trial 42 with value: 0.8954940187190087.
# [I 2025-11-10 15:02:21,131] Trial 45 finished with value: 0.8931489791658455 and parameters: {'n_estimators': 592, 'max_depth': 4, 'learning_rate': 0.10764465643672065, 'subsample': 0.891547960044823, 'colsample_bytree': 0.760758238761191, 'gamma': 2.2211719847025155, 'min_child_weight': 12, 'scale_pos_weight': 68.38164452382506}. Best is trial 42 with value: 0.8954940187190087.
# [I 2025-11-10 15:02:25,484] Trial 46 finished with value: 0.8811260356815351 and parameters: {'n_estimators': 207, 'max_depth': 3, 'learning_rate': 0.02891636220082243, 'subsample': 0.9064932637319171, 'colsample_bytree': 0.8327985901658004, 'gamma': 2.8412626483477297, 'min_child_weight': 16, 'scale_pos_weight': 91.00526451640349}. Best is trial 42 with value: 0.8954940187190087.
# [I 2025-11-10 15:02:31,315] Trial 47 finished with value: 0.881561042929125 and parameters: {'n_estimators': 724, 'max_depth': 9, 'learning_rate': 0.07530931389686096, 'subsample': 0.9309123875609218, 'colsample_bytree': 0.8891304489790679, 'gamma': 3.74032447694955, 'min_child_weight': 15, 'scale_pos_weight': 56.374473750590205}. Best is trial 42 with value: 0.8954940187190087.
# [I 2025-11-10 15:02:35,190] Trial 48 finished with value: 0.8925237218812584 and parameters: {'n_estimators': 677, 'max_depth': 5, 'learning_rate': 0.16115425651223703, 'subsample': 0.8509189124152023, 'colsample_bytree': 0.7992624562103078, 'gamma': 3.3884211160452464, 'min_child_weight': 8, 'scale_pos_weight': 48.650182188684475}. Best is trial 42 with value: 0.8954940187190087.
# [I 2025-11-10 15:02:49,351] Trial 49 finished with value: 0.8950521387013534 and parameters: {'n_estimators': 767, 'max_depth': 3, 'learning_rate': 0.038103348327046205, 'subsample': 0.8788999842712945, 'colsample_bytree': 0.8483333577291472, 'gamma': 1.7246444005111143, 'min_child_weight': 13, 'scale_pos_weight': 66.246787445207}. Best is trial 42 with value: 0.8954940187190087.
# Best params: {'n_estimators': 668, 'max_depth': 4, 'learning_rate': 0.041220581254456184, 'subsample': 0.8866972561799367, 'colsample_bytree': 0.8225361744537156, 'gamma': 2.977080553654553, 'min_child_weight': 11, 'scale_pos_weight': 56.656079473016156}

# %%
# Extract best parameters
best_params = study.best_params  # from Optuna study

# Train final model on full training set
final_model = XGBClassifier(**best_params)
final_model.fit(X_train_nolog, y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8225361744537156, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, feature_weights=None,
#               gamma=2.977080553654553, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.041220581254456184,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=11, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=668, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
# Evaluate on Train Set
y_train_pred = final_model.predict(X_train_nolog)
y_train_proba = final_model.predict_proba(X_train_nolog)[:, 1]

# Classification report
print("Final Model Training Classification Report:\n")
print(classification_report(y_train, y_train_pred, digits=4))

# ROC-AUC
roc_auc_train = roc_auc_score(y_train, y_train_proba)
print(f"Final Model Training ROC-AUC Score: {roc_auc_train:.4f}")

# PR-AUC
pr_auc_train = average_precision_score(y_train, y_train_proba)
print(f"Final Model Training PR-AUC Score: {pr_auc_train:.4f}") 

# Confusion matrix
print("Final Model Training Confusion Matrix:\n", confusion_matrix(y_train, y_train_pred))
# Out:
# Final Model Training Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9974    0.8985    0.9454    786838
#            1     0.0732    0.7734    0.1337      8151
#
#     accuracy                         0.8972    794989
#    macro avg     0.5353    0.8360    0.5395    794989
# weighted avg     0.9879    0.8972    0.9371    794989
#
# Final Model Training ROC-AUC Score: 0.9290
# Final Model Training PR-AUC Score: 0.1976
# Final Model Training Confusion Matrix:
#  [[706998  79840]
#  [  1847   6304]]

# %%
# Evaluate on Validation Set
y_val_pred = final_model.predict(X_val_nolog)
y_val_proba = final_model.predict_proba(X_val_nolog)[:, 1]

# Classification report
print("\nFinal Model Validation Classification Report:\n")
print(classification_report(y_val, y_val_pred, digits=4))

# ROC-AUC
roc_auc_val = roc_auc_score(y_val, y_val_proba)
print(f"Final Model Validation ROC-AUC Score: {roc_auc_val:.4f}")

# PR-AUC
pr_auc_val = average_precision_score(y_val, y_val_proba)
print(f"Final Model Validation PR-AUC Score: {pr_auc_val:.4f}")

# Confusion matrix
print("Final Model Validation Confusion Matrix:\n", confusion_matrix(y_val, y_val_pred))
# Out:
# Final Model Validation Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9960    0.8675    0.9273    106718
#            1     0.0710    0.7455    0.1297      1450
#
#     accuracy                         0.8658    108168
#    macro avg     0.5335    0.8065    0.5285    108168
# weighted avg     0.9836    0.8658    0.9166    108168
#
# Final Model Validation ROC-AUC Score: 0.8946
# Final Model Validation PR-AUC Score: 0.1815
# Final Model Validation Confusion Matrix:
#  [[92576 14142]
#  [  369  1081]]

# %%
# Evaluate on Test Set
y_test_pred = final_model.predict(X_test_nolog)
y_test_proba = final_model.predict_proba(X_test_nolog)[:, 1]
# Classification report
print("\nTest Classification Report:\n")
print(classification_report(y_test, y_test_pred, digits=4))
# ROC-AUC
roc_auc_test = roc_auc_score(y_test, y_test_proba)
print(f"Test ROC-AUC Score: {roc_auc_test:.4f}")
# PR-AUC
pr_auc_test = average_precision_score(y_test, y_test_proba)
print(f"Test PR-AUC Score: {pr_auc_test:.4f}")
# Confusion matrix
print("Test Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred))
# Out:
# Test Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9952    0.8842    0.9364     95415
#            1     0.0847    0.7157    0.1514      1428
#
#     accuracy                         0.8817     96843
#    macro avg     0.5399    0.8000    0.5439     96843
# weighted avg     0.9818    0.8817    0.9249     96843
#
# Test ROC-AUC Score: 0.8971
# Test PR-AUC Score: 0.2150
# Test Confusion Matrix:
#  [[84368 11047]
#  [  406  1022]]
